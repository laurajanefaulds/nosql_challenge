# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Notebook Set Up

# %%
# Import dependencies
from pymongo import MongoClient
import pandas as pd
from pprint import pprint
pd.options.display.max_colwidth = 30

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# assign the uk_food database to a variable name
db = mongo['uk_food']

# %%
# review the collections in our database
print(db.list_collection_names())
# Out:
# ['establishments']

# %%
# assign the collection to a variable
establishments = db['establishments']

# %% [markdown]
# ## Part 3: Exploratory Analysis
# Unless otherwise stated, for each question:
# * Use `count_documents` to display the number of documents contained in the result.
# * Display the first document in the results using `pprint`.
# * Convert the result to a Pandas DataFrame, print the number of rows in the DataFrame, and display the first 10 rows.

# %% [markdown]
# ### 1. Which establishments have a hygiene score equal to 20?

# %%
# Find the establishments with a hygiene score of 20
hygiene_query = {'scores.Hygiene': 20}


# Use count_documents to display the number of documents in the result
# Print the number of results

total_hygiene = establishments.count_documents(hygiene_query)
print("Total documents in result:", total_hygiene)

# Display the first document in the results using pprint
result = establishments.find_one(hygiene_query)
pprint(result)
# Out:
# Total documents in result: 41
# {'AddressLine1': '5-6 Southfields Road',
#  'AddressLine2': 'Eastbourne',
#  'AddressLine3': 'East Sussex',
#  'AddressLine4': '',
#  'BusinessName': 'The Chase Rest Home',
#  'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  'ChangesByServerID': 0,
#  'Distance': 4613.888288172291,
#  'FHRSID': 110681,
#  'LocalAuthorityBusinessID': '4029',
#  'LocalAuthorityCode': '102',
#  'LocalAuthorityEmailAddress': 'Customerfirst@eastbourne.gov.uk',
#  'LocalAuthorityName': 'Eastbourne',
#  'LocalAuthorityWebSite': 'http://www.eastbourne.gov.uk/foodratings',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'BN21 1BU',
#  'RatingDate': '2021-09-23T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': 0,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64be8ec0a8ac077a10702472'),
#  'geocode': {'latitude': Decimal128('50.769705'),
#              'longitude': Decimal128('0.27694')},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/110681',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 20, 'Structural': 20}}

# %%
# Convert the result to a Pandas DataFrame
results_for_df = list(establishments.find(hygiene_query))

hygiene_df = pd.DataFrame(results_for_df)

# Display the number of rows in the DataFrame
print(len(hygiene_df))

# Display the first 10 rows of the DataFrame
hygiene_df.head(10)
# Out:
# 41
#                         _id   FHRSID  ChangesByServerID  \
# 0  64be8ec0a8ac077a10702472   110681                  0
# 1  64be8ec0a8ac077a107027f8   612039                  0
# 2  64be8ec0a8ac077a10702b00   730933                  0
# 3  64be8ec0a8ac077a10702cf0   172735                  0
# 4  64be8ec0a8ac077a10702cfb   172953                  0
# 5  64be8ec0a8ac077a10703699   512854                  0
# 6  64be8ec0a8ac077a107038c1  1537089                  0
# 7  64be8ec0a8ac077a10704de8   155648                  0
# 8  64be8ec0a8ac077a10705231  1012883                  0
# 9  64be8ec0a8ac077a10705a41   644109                  0
#
#   LocalAuthorityBusinessID               BusinessName  \
# 0                     4029        The Chase Rest Home
# 1                1970/FOOD                 Brenalwood
# 2                1698/FOOD              Melrose Hotel
# 3             PI/000023858              Seaford Pizza
# 4             PI/000024532              Golden Palace
# 5            12/00816/BUTH           Ashby's Butchers
# 6          22/00224/RESTUN  South Sea Express Cuisine
# 7              EH/00006058              Golden Palace
# 8         17/00110/MIXED/S             The Tulip Tree
# 9                    41811                      F & S
#
#                     BusinessType  BusinessTypeID           AddressLine1  \
# 0                Caring Premises               5   5-6 Southfields Road
# 1                Caring Premises               5              Hall Lane
# 2  Hotel/bed & breakfast/gues...            7842  53 Marine Parade East
# 3         Takeaway/sandwich shop            7844          4 High Street
# 4        Restaurant/Cafe/Canteen               1         5 South Street
# 5              Retailers - other            4613   777 Southchurch Road
# 6        Restaurant/Cafe/Canteen               1    33 Alexandra Street
# 7         Takeaway/sandwich shop            7844          7 London Road
# 8        Restaurant/Cafe/Canteen               1          3 The Village
# 9              Retailers - other            4613
#
#          AddressLine2 AddressLine3  ...          LocalAuthorityWebSite  \
# 0          Eastbourne  East Sussex  ...  http://www.eastbourne.gov....
# 1  Walton-on-the-Naze        Essex  ...  http://www.tendringdc.gov.uk/
# 2      Clacton On Sea        Essex  ...  http://www.tendringdc.gov.uk/
# 3             Seaford  East Sussex  ...  http://www.lewes-eastbourn...
# 4             Seaford  East Sussex  ...  http://www.lewes-eastbourn...
# 5     Southend-On-Sea        Essex  ...     http://www.southend.gov.uk
# 6     Southend-on-sea        Essex  ...     http://www.southend.gov.uk
# 7            Rayleigh        Essex  ...     http://www.rochford.gov.uk
# 8       Chiddingstone         KENT  ...   http://www.sevenoaks.gov.uk/
# 9      81 Southernhay     Basildon  ...     http://www.basildon.gov.uk
#
#       LocalAuthorityEmailAddress                         scores  SchemeType  \
# 0  Customerfirst@eastbourne.g...  {'Hygiene': 20, 'Structura...        FHRS
# 1     fhsadmin@tendringdc.gov.uk  {'Hygiene': 20, 'Structura...        FHRS
# 2     fhsadmin@tendringdc.gov.uk  {'Hygiene': 20, 'Structura...        FHRS
# 3  ehealth.ldc@lewes-eastbour...  {'Hygiene': 20, 'Structura...        FHRS
# 4  ehealth.ldc@lewes-eastbour...  {'Hygiene': 20, 'Structura...        FHRS
# 5  EnvironmentalHealth@southe...  {'Hygiene': 20, 'Structura...        FHRS
# 6  EnvironmentalHealth@southe...  {'Hygiene': 20, 'Structura...        FHRS
# 7  customerservices@rochford....  {'Hygiene': 20, 'Structura...        FHRS
# 8  environmental.health@seven...  {'Hygiene': 20, 'Structura...        FHRS
# 9            ehs@basildon.gov.uk  {'Hygiene': 20, 'Structura...        FHRS
#
#                          geocode RightToReply     Distance NewRatingPending  \
# 0  {'longitude': 0.27694, 'la...               4613.888288            False
# 1  {'longitude': 1.278721, 'l...               4617.965824            False
# 2  {'longitude': 1.15927, 'la...               4619.656144            False
# 3  {'longitude': 0.10202, 'la...               4620.421725            False
# 4  {'longitude': 0.101446, 'l...               4620.437179            False
# 5  {'longitude': 0.736349, 'l...               4625.565258            False
# 6  {'longitude': 0.7121671, '...               4626.200132            False
# 7  {'longitude': 0.602364, 'l...               4632.276890            False
# 8  {'longitude': 0.1464499980...               4633.934041            False
# 9  {'longitude': 0.462307, 'l...               4636.552523            False
#
#                             meta                          links
# 0  {'dataSource': None, 'extr...  [{'rel': 'self', 'href': '...
# 1  {'dataSource': None, 'extr...  [{'rel': 'self', 'href': '...
# 2  {'dataSource': None, 'extr...  [{'rel': 'self', 'href': '...
# 3  {'dataSource': None, 'extr...  [{'rel': 'self', 'href': '...
# 4  {'dataSource': None, 'extr...  [{'rel': 'self', 'href': '...
# 5  {'dataSource': None, 'extr...  [{'rel': 'self', 'href': '...
# 6  {'dataSource': None, 'extr...  [{'rel': 'self', 'href': '...
# 7  {'dataSource': None, 'extr...  [{'rel': 'self', 'href': '...
# 8  {'dataSource': None, 'extr...  [{'rel': 'self', 'href': '...
# 9  {'dataSource': None, 'extr...  [{'rel': 'self', 'href': '...
#
# [10 rows x 28 columns]

# %% [markdown]
# ### 2. Which establishments in London have a `RatingValue` greater than or equal to 4?

# %%
# Find the establishments with London as the Local Authority and has a RatingValue greater than or equal to 4.

london_query = {'$and': [{'LocalAuthorityName': {'$regex': 'London'}}, {'RatingValue': {'$gte': 4}}]}
                
# Use count_documents to display the number of documents in the result
total_london = establishments.count_documents(london_query)
print("Total documents in result:", total_london)

# Display the first document in the results using pprint
results = list(establishments.find(london_query))
for result in results:
    pprint(result)
# Out:
# Total documents in result: 33
# {'AddressLine1': 'Oak Apple Farm Building 103 Sheernes Docks',
#  'AddressLine2': 'Sheppy Kent',
#  'AddressLine3': '',
#  'AddressLine4': '',
#  'BusinessName': "Charlie's",
#  'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  'ChangesByServerID': 0,
#  'Distance': 4627.439467780196,
#  'FHRSID': 621707,
#  'LocalAuthorityBusinessID': 'PI/000025307',
#  'LocalAuthorityCode': '508',
#  'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#  'LocalAuthorityName': 'City of London Corporation',
#  'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'ME12',
#  'RatingDate': '2021-10-18T00:00:00',
#  'RatingKey': 'fhrs_4_en-gb',
#  'RatingValue': 4,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64be8ec0a8ac077a10703e96'),
#  'geocode': {'latitude': Decimal128('51.369321'),
#              'longitude': Decimal128('0.508551')},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/621707',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 10}}
# {'AddressLine1': 'Cherry Garden Pier',
#  'AddressLine2': 'Cherry Garden Street Rotherhithe',
#  'AddressLine3': 'Charlton',
#  'AddressLine4': '',
#  'BusinessName': 'Mv City Cruises Erasmus',
#  'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  'ChangesByServerID': 0,
#  'Distance': 4627.8731788858,
#  'FHRSID': 1130836,
#  'LocalAuthorityBusinessID': 'PI/000034075',
#  'LocalAuthorityCode': '508',
#  'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#  'LocalAuthorityName': 'City of London Corporation',
#  'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'TN4 8HR',
#  'RatingDate': '2021-05-14T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64be8ec0a8ac077a107041c0'),
#  'geocode': {'latitude': Decimal128('51.1236228942871'),
#              'longitude': Decimal128('0.249255999922752')},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1130836',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 5}}
# {'AddressLine1': 'Ferry Road',
#  'AddressLine2': 'South Benfleet Essex',
#  'AddressLine3': '',
#  'AddressLine4': '',
#  'BusinessName': 'Benfleet Motor Yacht Club',
#  'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  'ChangesByServerID': 0,
#  'Distance': 4631.968418191259,
#  'FHRSID': 293783,
#  'LocalAuthorityBusinessID': 'PI/000002614',
#  'LocalAuthorityCode': '508',
#  'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#  'LocalAuthorityName': 'City of London Corporation',
#  'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'SS7 1NF',
#  'RatingDate': '2018-11-02T00:00:00',
#  'RatingKey': 'fhrs_4_en-gb',
#  'RatingValue': 4,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64be8ec0a8ac077a10704d03'),
#  'geocode': {'latitude': Decimal128('51.543831'),
#              'longitude': Decimal128('0.561954')},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/293783',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 10, 'Hygiene': 0, 'Structural': 0}}
# {'AddressLine1': 'Leslie Ford House',
#  'AddressLine2': 'Tilbury',
#  'AddressLine3': 'Charlton',
#  'AddressLine4': '',
#  'BusinessName': 'Coombs Catering t/a The Lock and Key',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4636.846754121153,
#  'FHRSID': 1315095,
#  'LocalAuthorityBusinessID': 'PI/000036464',
#  'LocalAuthorityCode': '508',
#  'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#  'LocalAuthorityName': 'City of London Corporation',
#  'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'RM18 7EH',
#  'RatingDate': '2020-12-04T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64be8ec0a8ac077a10705b02'),
#  'geocode': {'latitude': Decimal128('51.4640655517578'),
#              'longitude': Decimal128('0.346336990594864')},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1315095',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 5}}
# {'AddressLine1': 'Tenants Row Tilbury Docks',
#  'AddressLine2': 'Tilbury Essex',
#  'AddressLine3': '',
#  'AddressLine4': '',
#  'BusinessName': 'Tilbury Seafarers Centre',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4636.847649796817,
#  'FHRSID': 294474,
#  'LocalAuthorityBusinessID': 'PI/000014647',
#  'LocalAuthorityCode': '508',
#  'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#  'LocalAuthorityName': 'City of London Corporation',
#  'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'RM18 7EH',
#  'RatingDate': '2018-11-02T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64be8ec0a8ac077a10705b0f'),
#  'geocode': {'latitude': Decimal128('51.464078'),
#              'longitude': Decimal128('0.346325')},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/294474',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}}
# {'AddressLine1': 'Reeds River Cruises LtdKings ReachRiver ThamesSouthwark',
#  'AddressLine2': 'London',
#  'AddressLine3': '',
#  'AddressLine4': '',
#  'BusinessName': 'Mv Valulla',
#  'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  'ChangesByServerID': 0,
#  'Distance': 4640.460834256174,
#  'FHRSID': 294900,
#  'LocalAuthorityBusinessID': 'PI/000019066',
#  'LocalAuthorityCode': '508',
#  'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#  'LocalAuthorityName': 'City of London Corporation',
#  'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'RM15 5QY',
#  'RatingDate': '2016-08-23T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64be8ec0a8ac077a10706209'),
#  'geocode': {'latitude': Decimal128('51.504071'),
#              'longitude': Decimal128('0.287555')},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/294900',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}}
# {'AddressLine1': 'Funcraft UK Ltd King George V Dock Woolwich Manor Way',
#  'AddressLine2': 'London',
#  'AddressLine3': '',
#  'AddressLine4': '',
#  'BusinessName': 'Tereza Joanne',
#  'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  'ChangesByServerID': 0,
#  'Distance': 4648.301822363946,
#  'FHRSID': 293756,
#  'LocalAuthorityBusinessID': 'PI/000002538',
#  'LocalAuthorityCode': '508',
#  'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#  'LocalAuthorityName': 'City of London Corporation',
#  'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'E16 2NJ',
#  'RatingDate': '2021-07-09T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64be8ec1a8ac077a10708322'),
#  'geocode': {'latitude': Decimal128('51.501121'),
#              'longitude': Decimal128('0.069286')},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/293756',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 0, 'Structural': 5}}
# {'AddressLine1': 'Air side London City Airport',
#  'AddressLine2': 'London',
#  'AddressLine3': '',
#  'AddressLine4': '',
#  'BusinessName': 'Brick Lane Brews',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4649.1734848484375,
#  'FHRSID': 878523,
#  'LocalAuthorityBusinessID': 'PI/000029844',
#  'LocalAuthorityCode': '508',
#  'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#  'LocalAuthorityName': 'City of London Corporation',
#  'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'E16 2PX',
#  'RatingDate': '2019-01-18T00:00:00',
#  'RatingKey': 'fhrs_4_en-gb',
#  'RatingValue': 4,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64be8ec1a8ac077a107086df'),
#  'geocode': {'latitude': Decimal128('51.503733'),
#              'longitude': Decimal128('0.048006')},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/878523',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 10, 'Structural': 5}}
# {'AddressLine1': 'Duty Free Shop Passenger Terminal',
#  'AddressLine2': 'London City AirportRoyal DocksLondon',
#  'AddressLine3': '',
#  'AddressLine4': '',
#  'BusinessName': 'The Nuance Group (UK) Limited',
#  'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  'ChangesByServerID': 0,
#  'Distance': 4649.188825980348,
#  'FHRSID': 293772,
#  'LocalAuthorityBusinessID': 'PI/000002585',
#  'LocalAuthorityCode': '508',
#  'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#  'LocalAuthorityName': 'City of London Corporation',
#  'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'E16 2PX',
#  'RatingDate': '2017-07-17T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64be8ec1a8ac077a107086f8'),
#  'geocode': {'latitude': Decimal128('51.504112'),
#              'longitude': Decimal128('0.047966')},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/293772',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}}
# {'AddressLine1': 'London City Airport',
#  'AddressLine2': 'Silvertown London',
#  'AddressLine3': '',
#  'AddressLine4': '',
#  'BusinessName': 'WH Smith',
#  'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  'ChangesByServerID': 0,
#  'Distance': 4649.188850403149,
#  'FHRSID': 294606,
#  'LocalAuthorityBusinessID': 'PI/000016185',
#  'LocalAuthorityCode': '508',
#  'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#  'LocalAuthorityName': 'City of London Corporation',
#  'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'E16 2PX',
#  'RatingDate': '2017-07-17T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64be8ec1a8ac077a107086f9'),
#  'geocode': {'latitude': Decimal128('51.5041122436523'),
#              'longitude': Decimal128('0.0479655750095844')},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/294606',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}}
# {'AddressLine1': 'London City Airport (Airside)',
#  'AddressLine2': 'London',
#  'AddressLine3': '',
#  'AddressLine4': '',
#  'BusinessName': 'City Bar & Grill',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4649.188850403149,
#  'FHRSID': 295107,
#  'LocalAuthorityBusinessID': 'PI/000020749',
#  'LocalAuthorityCode': '508',
#  'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#  'LocalAuthorityName': 'City of London Corporation',
#  'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'E16 2PX',
#  'RatingDate': '2021-12-06T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64be8ec1a8ac077a107086fb'),
#  'geocode': {'latitude': Decimal128('51.5041122436523'),
#              'longitude': Decimal128('0.0479655750095844')},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/295107',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 5}}
# {'AddressLine1': 'London City Airport Airside Departure Lounge',
#  'AddressLine2': 'Royal Docks London',
#  'AddressLine3': '',
#  'AddressLine4': '',
#  'BusinessName': 'Caffè Nero',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4649.485929427517,
#  'FHRSID': 294616,
#  'LocalAuthorityBusinessID': 'PI/000016269',
#  'LocalAuthorityCode': '508',
#  'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#  'LocalAuthorityName': 'City of London Corporation',
#  'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'E16 2PJ',
#  'RatingDate': '2021-11-12T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64be8ec1a8ac077a107088d9'),
#  'geocode': {'latitude': Decimal128('51.504808'),
#              'longitude': Decimal128('0.040518')},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/294616',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 0, 'Hygiene': 5, 'Structural': 5}}
# {'AddressLine1': 'London City Airport',
#  'AddressLine2': 'Royal Docks London',
#  'AddressLine3': '',
#  'AddressLine4': '',
#  'BusinessName': 'Jet Centre',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4649.48586971274,
#  'FHRSID': 294523,
#  'LocalAuthorityBusinessID': 'PI/000015222',
#  'LocalAuthorityCode': '508',
#  'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#  'LocalAuthorityName': 'City of London Corporation',
#  'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'E16 2PJ',
#  'RatingDate': '2022-02-11T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64be8ec1a8ac077a107088da'),
#  'geocode': {'latitude': Decimal128('51.5048065185547'),
#              'longitude': Decimal128('0.0405181497335434')},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/294523',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}}
# {'AddressLine1': 'Western Gateway',
#  'AddressLine2': 'Royal Victoria Dock',
#  'AddressLine3': '',
#  'AddressLine4': '',
#  'BusinessName': 'Mv Sunborn Yacht Hotel',
#  'BusinessType': 'Hotel/bed & breakfast/guest house',
#  'BusinessTypeID': 7842,
#  'ChangesByServerID': 0,
#  'Distance': 4650.0981296859945,
#  'FHRSID': 1427985,
#  'LocalAuthorityBusinessID': 'PI/000037871',
#  'LocalAuthorityCode': '508',
#  'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#  'LocalAuthorityName': 'City of London Corporation',
#  'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'E16 1XL',
#  'RatingDate': '2021-11-19T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64be8ec1a8ac077a10708b79'),
#  'geocode': {'latitude': Decimal128('51.50817'),
#              'longitude': Decimal128('0.027107')},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1427985',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 5}}
# {'AddressLine1': 'Western Gateway Royal Victoria Dock',
#  'AddressLine2': 'Floating Platform next to Emirates Cable Car',
#  'AddressLine3': '',
#  'AddressLine4': '',
#  'BusinessName': 'Good Hotel London',
#  'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  'ChangesByServerID': 0,
#  'Distance': 4650.415301460256,
#  'FHRSID': 934211,
#  'LocalAuthorityBusinessID': 'PI/000030457',
#  'LocalAuthorityCode': '508',
#  'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#  'LocalAuthorityName': 'City of London Corporation',
#  'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'E16 1FA',
#  'RatingDate': '2021-07-16T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64be8ec1a8ac077a10708d86'),
#  'geocode': {'latitude': Decimal128('51.507681'),
#              'longitude': Decimal128('0.01792')},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/934211',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 5}}
# {'AddressLine1': 'Dock Road',
#  'AddressLine2': 'London',
#  'AddressLine3': 'Charlton',
#  'AddressLine4': '',
#  'BusinessName': 'La Nonna lina',
#  'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  'ChangesByServerID': 0,
#  'Distance': 4650.4320658321685,
#  'FHRSID': 1392440,
#  'LocalAuthorityBusinessID': 'PI/000037382',
#  'LocalAuthorityCode': '508',
#  'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#  'LocalAuthorityName': 'City of London Corporation',
#  'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'E16 1AG',
#  'RatingDate': '2021-10-01T00:00:00',
#  'RatingKey': 'fhrs_4_en-gb',
#  'RatingValue': 4,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64be8ec1a8ac077a10708dab'),
#  'geocode': {'latitude': Decimal128('51.5059814453125'),
#              'longitude': Decimal128('0.0157549995929003')},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1392440',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 0, 'Structural': 10}}
# {'AddressLine1': 'Western Beach Royal Victoria Docks',
#  'AddressLine2': 'London',
#  'AddressLine3': 'Charlton',
#  'AddressLine4': '',
#  'BusinessName': 'Wake Up Docklands Limited',
#  'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  'ChangesByServerID': 0,
#  'Distance': 4650.432926312135,
#  'FHRSID': 558640,
#  'LocalAuthorityBusinessID': 'PI/000024155',
#  'LocalAuthorityCode': '508',
#  'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#  'LocalAuthorityName': 'City of London Corporation',
#  'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'E16 1AG',
#  'RatingDate': '2018-11-05T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64be8ec1a8ac077a10708db0'),
#  'geocode': {'latitude': Decimal128('51.505992'),
#              'longitude': Decimal128('0.015742')},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/558640',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}}
# {'AddressLine1': 'Trinity Buoy Wharf',
#  'AddressLine2': 'Orchard Place',
#  'AddressLine3': '',
#  'AddressLine4': '',
#  'BusinessName': 'MV Venus Clipper',
#  'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  'ChangesByServerID': 0,
#  'Distance': 4650.747348950763,
#  'FHRSID': 1498024,
#  'LocalAuthorityBusinessID': 'PI/000038347',
#  'LocalAuthorityCode': '508',
#  'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#  'LocalAuthorityName': 'City of London Corporation',
#  'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'E14 0JY',
#  'RatingDate': '2022-02-25T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64be8ec1a8ac077a10708f7b'),
#  'geocode': {'latitude': Decimal128('51.507771887145'),
#              'longitude': Decimal128('0.00890800673629534')},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1498024',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}}
# {'AddressLine1': 'Thames Clippers Unit 12 The Riverside Building',
#  'AddressLine2': '64 Orchard Place Trinity Buoy Wharf London',
#  'AddressLine3': '',
#  'AddressLine4': '',
#  'BusinessName': 'MV Typhoon clipper',
#  'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  'ChangesByServerID': 0,
#  'Distance': 4650.805007769328,
#  'FHRSID': 1090020,
#  'LocalAuthorityBusinessID': 'PI/000033476',
#  'LocalAuthorityCode': '508',
#  'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#  'LocalAuthorityName': 'City of London Corporation',
#  'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'E14 0JY',
#  'RatingDate': '2018-12-14T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64be8ec1a8ac077a10708fc0'),
#  'geocode': {'latitude': Decimal128('51.508259'),
#              'longitude': Decimal128('0.007816')},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1090020',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}}
# {'AddressLine1': 'Thames Clippers 3rd flr Clippers House',
#  'AddressLine2': 'Orchard Place Trinity Buoy Wharf London',
#  'AddressLine3': '',
#  'AddressLine4': '',
#  'BusinessName': 'MV Moon clipper',
#  'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  'ChangesByServerID': 0,
#  'Distance': 4650.805001170512,
#  'FHRSID': 1090017,
#  'LocalAuthorityBusinessID': 'PI/000033472',
#  'LocalAuthorityCode': '508',
#  'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#  'LocalAuthorityName': 'City of London Corporation',
#  'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'E14 0JY',
#  'RatingDate': '2018-09-25T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64be8ec1a8ac077a10708fc3'),
#  'geocode': {'latitude': Decimal128('51.5082588195801'),
#              'longitude': Decimal128('0.0078159999102354')},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1090017',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}}
# {'AddressLine1': 'Thames Clippers Unit 12 The Riverside Building',
#  'AddressLine2': '64 Orchard Place Trinity Buoy Wharf London',
#  'AddressLine3': '',
#  'AddressLine4': '',
#  'BusinessName': 'MV Jupiter clipper',
#  'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  'ChangesByServerID': 0,
#  'Distance': 4650.805007769328,
#  'FHRSID': 1090023,
#  'LocalAuthorityBusinessID': 'PI/000033479',
#  'LocalAuthorityCode': '508',
#  'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#  'LocalAuthorityName': 'City of London Corporation',
#  'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'E14 0JY',
#  'RatingDate': '2018-12-14T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64be8ec1a8ac077a10708fc4'),
#  'geocode': {'latitude': Decimal128('51.508259'),
#              'longitude': Decimal128('0.007816')},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1090023',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}}
# {'AddressLine1': 'Thames Clippers Unit 12 The Riverside Building',
#  'AddressLine2': '64 Orchard Place Trinity Buoy Wharf London',
#  'AddressLine3': '',
#  'AddressLine4': '',
#  'BusinessName': 'MV Meteor clipper',
#  'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  'ChangesByServerID': 0,
#  'Distance': 4650.805007769328,
#  'FHRSID': 1090022,
#  'LocalAuthorityBusinessID': 'PI/000033478',
#  'LocalAuthorityCode': '508',
#  'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#  'LocalAuthorityName': 'City of London Corporation',
#  'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'E14 0JY',
#  'RatingDate': '2018-12-14T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64be8ec1a8ac077a10708fc5'),
#  'geocode': {'latitude': Decimal128('51.508259'),
#              'longitude': Decimal128('0.007816')},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1090022',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}}
# {'AddressLine1': 'Thames Clippers 3rd flr Clippers House',
#  'AddressLine2': 'Orchard Place Trinity Buoy Wharf London',
#  'AddressLine3': '',
#  'AddressLine4': '',
#  'BusinessName': 'MV Mercury clipper',
#  'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  'ChangesByServerID': 0,
#  'Distance': 4650.805001170512,
#  'FHRSID': 1090018,
#  'LocalAuthorityBusinessID': 'PI/000033473',
#  'LocalAuthorityCode': '508',
#  'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#  'LocalAuthorityName': 'City of London Corporation',
#  'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'E14 0JY',
#  'RatingDate': '2018-12-14T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64be8ec1a8ac077a10708fc6'),
#  'geocode': {'latitude': Decimal128('51.5082588195801'),
#              'longitude': Decimal128('0.0078159999102354')},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1090018',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}}
# {'AddressLine1': 'Thames Clippers Unit 12 The Riverside Building',
#  'AddressLine2': '64 Orchard Place Trinity Buoy Wharf London',
#  'AddressLine3': '',
#  'AddressLine4': '',
#  'BusinessName': 'MV Monsoon clipper',
#  'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  'ChangesByServerID': 0,
#  'Distance': 4650.805007769328,
#  'FHRSID': 1090021,
#  'LocalAuthorityBusinessID': 'PI/000033477',
#  'LocalAuthorityCode': '508',
#  'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#  'LocalAuthorityName': 'City of London Corporation',
#  'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'E14 0JY',
#  'RatingDate': '2018-12-14T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64be8ec1a8ac077a10708fc7'),
#  'geocode': {'latitude': Decimal128('51.508259'),
#              'longitude': Decimal128('0.007816')},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1090021',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}}
# {'AddressLine1': 'Thames Clippers Unit 12 The Riverside Building',
#  'AddressLine2': '64 Orchard Place Trinity Buoy Wharf London',
#  'AddressLine3': '',
#  'AddressLine4': '',
#  'BusinessName': 'MV Neptune clipper',
#  'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  'ChangesByServerID': 0,
#  'Distance': 4650.805007769328,
#  'FHRSID': 1090028,
#  'LocalAuthorityBusinessID': 'PI/000033484',
#  'LocalAuthorityCode': '508',
#  'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#  'LocalAuthorityName': 'City of London Corporation',
#  'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'E14 0JY',
#  'RatingDate': '2018-05-02T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64be8ec1a8ac077a10708fc8'),
#  'geocode': {'latitude': Decimal128('51.508259'),
#              'longitude': Decimal128('0.007816')},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1090028',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}}
# {'AddressLine1': 'Thames Clippers Unit 12 The Riverside Building',
#  'AddressLine2': '64 Orchard Place Trinity Buoy Wharf London',
#  'AddressLine3': '',
#  'AddressLine4': '',
#  'BusinessName': 'MV Tornado clipper',
#  'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  'ChangesByServerID': 0,
#  'Distance': 4650.805007769328,
#  'FHRSID': 1090019,
#  'LocalAuthorityBusinessID': 'PI/000033475',
#  'LocalAuthorityCode': '508',
#  'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#  'LocalAuthorityName': 'City of London Corporation',
#  'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'E14 0JY',
#  'RatingDate': '2018-05-02T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64be8ec1a8ac077a10708fc9'),
#  'geocode': {'latitude': Decimal128('51.508259'),
#              'longitude': Decimal128('0.007816')},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1090019',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}}
# {'AddressLine1': 'Thames Clippers Unit 12 The Riverside Building',
#  'AddressLine2': '64 Orchard Place Trinity Buoy Wharf London',
#  'AddressLine3': '',
#  'AddressLine4': '',
#  'BusinessName': 'MV Cyclone clipper',
#  'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  'ChangesByServerID': 0,
#  'Distance': 4650.805007769328,
#  'FHRSID': 1090027,
#  'LocalAuthorityBusinessID': 'PI/000033483',
#  'LocalAuthorityCode': '508',
#  'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#  'LocalAuthorityName': 'City of London Corporation',
#  'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'E14 0JY',
#  'RatingDate': '2018-12-14T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64be8ec1a8ac077a10708fca'),
#  'geocode': {'latitude': Decimal128('51.508259'),
#              'longitude': Decimal128('0.007816')},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1090027',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}}
# {'AddressLine1': 'Thames Clippers Unit 12 The Riverside Building',
#  'AddressLine2': '64 Orchard Place Trinity Buoy Wharf London',
#  'AddressLine3': '',
#  'AddressLine4': '',
#  'BusinessName': 'MV Galaxy clipper',
#  'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  'ChangesByServerID': 0,
#  'Distance': 4650.805007769328,
#  'FHRSID': 1090024,
#  'LocalAuthorityBusinessID': 'PI/000033480',
#  'LocalAuthorityCode': '508',
#  'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#  'LocalAuthorityName': 'City of London Corporation',
#  'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'E14 0JY',
#  'RatingDate': '2018-05-02T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64be8ec1a8ac077a10708fcb'),
#  'geocode': {'latitude': Decimal128('51.508259'),
#              'longitude': Decimal128('0.007816')},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1090024',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}}
# {'AddressLine1': 'Thames Clippers 3rd flr Clippers House',
#  'AddressLine2': 'Orchard Place Trinity Buoy Wharf London',
#  'AddressLine3': '',
#  'AddressLine4': '',
#  'BusinessName': 'MV Sun clipper',
#  'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  'ChangesByServerID': 0,
#  'Distance': 4650.805001170512,
#  'FHRSID': 1090016,
#  'LocalAuthorityBusinessID': 'PI/000033470',
#  'LocalAuthorityCode': '508',
#  'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#  'LocalAuthorityName': 'City of London Corporation',
#  'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'E14 0JY',
#  'RatingDate': '2018-12-14T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64be8ec1a8ac077a10708fcc'),
#  'geocode': {'latitude': Decimal128('51.5082588195801'),
#              'longitude': Decimal128('0.0078159999102354')},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1090016',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}}
# {'AddressLine1': 'Thames Clippers Unit 12 The Riverside Building',
#  'AddressLine2': '64 Orchard Place Trinity Buoy Wharf London',
#  'AddressLine3': '',
#  'AddressLine4': '',
#  'BusinessName': 'MV Hurricane clipper',
#  'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  'ChangesByServerID': 0,
#  'Distance': 4650.805007769328,
#  'FHRSID': 1090025,
#  'LocalAuthorityBusinessID': 'PI/000033481',
#  'LocalAuthorityCode': '508',
#  'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#  'LocalAuthorityName': 'City of London Corporation',
#  'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'E14 0JY',
#  'RatingDate': '2018-12-14T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64be8ec1a8ac077a10708fce'),
#  'geocode': {'latitude': Decimal128('51.508259'),
#              'longitude': Decimal128('0.007816')},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1090025',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}}
# {'AddressLine1': 'Trinity Buoy Wharf',
#  'AddressLine2': '64 Orchard Place',
#  'AddressLine3': '',
#  'AddressLine4': '',
#  'BusinessName': 'Canary Wharf 1V',
#  'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  'ChangesByServerID': 0,
#  'Distance': 4650.805044246847,
#  'FHRSID': 1450220,
#  'LocalAuthorityBusinessID': 'PI/000038259',
#  'LocalAuthorityCode': '508',
#  'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#  'LocalAuthorityName': 'City of London Corporation',
#  'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'E14 0JY',
#  'RatingDate': '2022-02-25T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64be8ec1a8ac077a10708fd1'),
#  'geocode': {'latitude': Decimal128('51.508259'),
#              'longitude': Decimal128('0.007815')},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1450220',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}}
# {'AddressLine1': 'Thames Clippers Unit 12 The Riverside Building',
#  'AddressLine2': '64 Orchard Place Trinity Buoy Wharf London',
#  'AddressLine3': '',
#  'AddressLine4': '',
#  'BusinessName': 'MV Aurora clipper',
#  'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  'ChangesByServerID': 0,
#  'Distance': 4650.805007769328,
#  'FHRSID': 1090026,
#  'LocalAuthorityBusinessID': 'PI/000033482',
#  'LocalAuthorityCode': '508',
#  'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#  'LocalAuthorityName': 'City of London Corporation',
#  'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'E14 0JY',
#  'RatingDate': '2021-12-03T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64be8ec1a8ac077a10708fd3'),
#  'geocode': {'latitude': Decimal128('51.508259'),
#              'longitude': Decimal128('0.007816')},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1090026',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}}
# {'AddressLine1': 'Thames Clippers Unit 12 The Riverside Building',
#  'AddressLine2': '64 Orchard Place Trinity Buoy Wharf London',
#  'AddressLine3': '',
#  'AddressLine4': '',
#  'BusinessName': 'Mv Storm Clipper',
#  'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  'ChangesByServerID': 0,
#  'Distance': 4650.805007769328,
#  'FHRSID': 293758,
#  'LocalAuthorityBusinessID': 'PI/000002546',
#  'LocalAuthorityCode': '508',
#  'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#  'LocalAuthorityName': 'City of London Corporation',
#  'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'E14 0JY',
#  'RatingDate': '2019-01-11T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64be8ec1a8ac077a10708fdf'),
#  'geocode': {'latitude': Decimal128('51.508259'),
#              'longitude': Decimal128('0.007816')},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/293758',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}}

# %%
# Convert the result to a Pandas DataFrame
london_df = pd.DataFrame(results)

# Display the number of rows in the DataFrame
print(len(london_df))

# Display the first 10 rows of the DataFrame
london_df.head(10)
# Out:
# 33
#                         _id   FHRSID  ChangesByServerID  \
# 0  64be8ec0a8ac077a10703e96   621707                  0
# 1  64be8ec0a8ac077a107041c0  1130836                  0
# 2  64be8ec0a8ac077a10704d03   293783                  0
# 3  64be8ec0a8ac077a10705b02  1315095                  0
# 4  64be8ec0a8ac077a10705b0f   294474                  0
# 5  64be8ec0a8ac077a10706209   294900                  0
# 6  64be8ec1a8ac077a10708322   293756                  0
# 7  64be8ec1a8ac077a107086df   878523                  0
# 8  64be8ec1a8ac077a107086f8   293772                  0
# 9  64be8ec1a8ac077a107086f9   294606                  0
#
#   LocalAuthorityBusinessID                   BusinessName  \
# 0             PI/000025307                      Charlie's
# 1             PI/000034075        Mv City Cruises Erasmus
# 2             PI/000002614      Benfleet Motor Yacht Club
# 3             PI/000036464  Coombs Catering t/a The Lo...
# 4             PI/000014647       Tilbury Seafarers Centre
# 5             PI/000019066                     Mv Valulla
# 6             PI/000002538                  Tereza Joanne
# 7             PI/000029844               Brick Lane Brews
# 8             PI/000002585  The Nuance Group (UK) Limited
# 9             PI/000016185                       WH Smith
#
#               BusinessType  BusinessTypeID                   AddressLine1  \
# 0  Other catering premises            7841  Oak Apple Farm Building 10...
# 1  Other catering premises            7841             Cherry Garden Pier
# 2  Other catering premises            7841                     Ferry Road
# 3  Restaurant/Cafe/Canteen               1              Leslie Ford House
# 4  Restaurant/Cafe/Canteen               1      Tenants Row Tilbury Docks
# 5  Other catering premises            7841  Reeds River Cruises LtdKin...
# 6  Other catering premises            7841  Funcraft UK Ltd King Georg...
# 7  Restaurant/Cafe/Canteen               1   Air side London City Airport
# 8        Retailers - other            4613  Duty Free Shop Passenger T...
# 9        Retailers - other            4613            London City Airport
#
#                     AddressLine2 AddressLine3  ...  \
# 0                    Sheppy Kent               ...
# 1  Cherry Garden Street Rothe...     Charlton  ...
# 2           South Benfleet Essex               ...
# 3                        Tilbury     Charlton  ...
# 4                  Tilbury Essex               ...
# 5                         London               ...
# 6                         London               ...
# 7                         London               ...
# 8  London City AirportRoyal D...               ...
# 9              Silvertown London               ...
#
#            LocalAuthorityWebSite     LocalAuthorityEmailAddress  \
# 0  http://www.cityoflondon.go...  publicprotection@cityoflon...
# 1  http://www.cityoflondon.go...  publicprotection@cityoflon...
# 2  http://www.cityoflondon.go...  publicprotection@cityoflon...
# 3  http://www.cityoflondon.go...  publicprotection@cityoflon...
# 4  http://www.cityoflondon.go...  publicprotection@cityoflon...
# 5  http://www.cityoflondon.go...  publicprotection@cityoflon...
# 6  http://www.cityoflondon.go...  publicprotection@cityoflon...
# 7  http://www.cityoflondon.go...  publicprotection@cityoflon...
# 8  http://www.cityoflondon.go...  publicprotection@cityoflon...
# 9  http://www.cityoflondon.go...  publicprotection@cityoflon...
#
#                           scores  SchemeType                        geocode  \
# 0  {'Hygiene': 5, 'Structural...        FHRS  {'longitude': 0.508551, 'l...
# 1  {'Hygiene': 0, 'Structural...        FHRS  {'longitude': 0.2492559999...
# 2  {'Hygiene': 0, 'Structural...        FHRS  {'longitude': 0.561954, 'l...
# 3  {'Hygiene': 0, 'Structural...        FHRS  {'longitude': 0.3463369905...
# 4  {'Hygiene': 0, 'Structural...        FHRS  {'longitude': 0.346325, 'l...
# 5  {'Hygiene': 0, 'Structural...        FHRS  {'longitude': 0.287555, 'l...
# 6  {'Hygiene': 0, 'Structural...        FHRS  {'longitude': 0.069286, 'l...
# 7  {'Hygiene': 10, 'Structura...        FHRS  {'longitude': 0.048006, 'l...
# 8  {'Hygiene': 0, 'Structural...        FHRS  {'longitude': 0.047966, 'l...
# 9  {'Hygiene': 0, 'Structural...        FHRS  {'longitude': 0.0479655750...
#
#   RightToReply     Distance NewRatingPending                           meta  \
# 0               4627.439468            False  {'dataSource': None, 'extr...
# 1               4627.873179            False  {'dataSource': None, 'extr...
# 2               4631.968418            False  {'dataSource': None, 'extr...
# 3               4636.846754            False  {'dataSource': None, 'extr...
# 4               4636.847650            False  {'dataSource': None, 'extr...
# 5               4640.460834            False  {'dataSource': None, 'extr...
# 6               4648.301822            False  {'dataSource': None, 'extr...
# 7               4649.173485            False  {'dataSource': None, 'extr...
# 8               4649.188826            False  {'dataSource': None, 'extr...
# 9               4649.188850            False  {'dataSource': None, 'extr...
#
#                            links
# 0  [{'rel': 'self', 'href': '...
# 1  [{'rel': 'self', 'href': '...
# 2  [{'rel': 'self', 'href': '...
# 3  [{'rel': 'self', 'href': '...
# 4  [{'rel': 'self', 'href': '...
# 5  [{'rel': 'self', 'href': '...
# 6  [{'rel': 'self', 'href': '...
# 7  [{'rel': 'self', 'href': '...
# 8  [{'rel': 'self', 'href': '...
# 9  [{'rel': 'self', 'href': '...
#
# [10 rows x 28 columns]

# %% [markdown]
# ### 3. What are the top 5 establishments with a `RatingValue` rating value of 5, sorted by lowest hygiene score, nearest to the new restaurant added, "Penang Flavours"?

# %%
# Search within 0.01 degree on either side of the latitude and longitude.
# Rating value must equal 5
# Sort by hygiene score

degree_search = 0.01
latitude = 51.49014200
longitude = 0.08384000

query = {
    'geocode.latitude': {'$gte': latitude - degree_search, '$lte': latitude + degree_search},
    'geocode.longitude': {'$gte': longitude - degree_search, '$lte': longitude + degree_search},
    'RatingValue': 5
}

sort = [('scores.Hygiene', 1)]
limit = 5

# Print the results
results = list(establishments.find(query).sort(sort).limit(limit))
pprint(results)
# Out:
# [{'AddressLine1': 'Restaurant And Premises 107A Plumstead High Street',
#   'AddressLine2': '',
#   'AddressLine3': 'Plumstead',
#   'AddressLine4': 'Greenwich',
#   'BusinessName': 'Howe and Co Fish and Chips - Van 17',
#   'BusinessType': 'Mobile caterer',
#   'BusinessTypeID': 7846,
#   'ChangesByServerID': 0,
#   'Distance': 4646.95593107927,
#   'FHRSID': 1380578,
#   'LocalAuthorityBusinessID': '14425',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE18 1SE',
#   'RatingDate': '2021-11-11T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('64be8ec1a8ac077a10707cc2'),
#   'geocode': {'latitude': Decimal128('51.4875335693359'),
#               'longitude': Decimal128('0.0925370007753372')},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1380578',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}},
#  {'AddressLine1': '17 Lakedale Road',
#   'AddressLine2': '',
#   'AddressLine3': 'Plumstead',
#   'AddressLine4': 'Greenwich',
#   'BusinessName': 'Lumbini Grocery Ltd T/A Al-Iman',
#   'BusinessType': 'Retailers - other',
#   'BusinessTypeID': 4613,
#   'ChangesByServerID': 0,
#   'Distance': 4646.975587048333,
#   'FHRSID': 909912,
#   'LocalAuthorityBusinessID': 'PI/000201100',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE18 1PP',
#   'RatingDate': '2020-10-20T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('64be8ec1a8ac077a10707cee'),
#   'geocode': {'latitude': Decimal128('51.4871632'),
#               'longitude': Decimal128('0.0916256')},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/909912',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 5}},
#  {'AddressLine1': '35 Lakedale Road',
#   'AddressLine2': '',
#   'AddressLine3': 'Plumstead',
#   'AddressLine4': 'Greenwich',
#   'BusinessName': 'Atlantic Fish Bar',
#   'BusinessType': 'Takeaway/sandwich shop',
#   'BusinessTypeID': 7844,
#   'ChangesByServerID': 0,
#   'Distance': 4646.974611855838,
#   'FHRSID': 694478,
#   'LocalAuthorityBusinessID': 'PI/000086506',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE18 1PR',
#   'RatingDate': '2021-06-16T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('64be8ec1a8ac077a10707ceb'),
#   'geocode': {'latitude': Decimal128('51.4867296'),
#               'longitude': Decimal128('0.0912164')},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/694478',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 5, 'Hygiene': 0, 'Structural': 0}},
#  {'AddressLine1': '144 - 146 Plumstead High Street',
#   'AddressLine2': '',
#   'AddressLine3': 'Plumstead',
#   'AddressLine4': 'Greenwich',
#   'BusinessName': 'Iceland',
#   'BusinessType': 'Retailers - supermarkets/hypermarkets',
#   'BusinessTypeID': 7840,
#   'ChangesByServerID': 0,
#   'Distance': 4646.946071297699,
#   'FHRSID': 695223,
#   'LocalAuthorityBusinessID': 'PI/000178842',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE18 1JQ',
#   'RatingDate': '2019-11-13T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('64be8ec1a8ac077a10707ca4'),
#   'geocode': {'latitude': Decimal128('51.4871482849121'),
#               'longitude': Decimal128('0.0924199968576431')},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/695223',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 5, 'Hygiene': 0, 'Structural': 5}},
#  {'AddressLine1': '130 - 132 Plumstead High Street',
#   'AddressLine2': '',
#   'AddressLine3': 'Plumstead',
#   'AddressLine4': 'Greenwich',
#   'BusinessName': 'Volunteer',
#   'BusinessType': 'Pub/bar/nightclub',
#   'BusinessTypeID': 7843,
#   'ChangesByServerID': 0,
#   'Distance': 4646.965634598608,
#   'FHRSID': 694609,
#   'LocalAuthorityBusinessID': 'PI/000116619',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE18 1JQ',
#   'RatingDate': '2019-08-05T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('64be8ec1a8ac077a10707cd2'),
#   'geocode': {'latitude': Decimal128('51.4873437'),
#               'longitude': Decimal128('0.09208')},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/694609',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}}]

# %%
# Convert the result to a Pandas DataFrame
lat_long_df = pd.DataFrame(results)

# Display the number of rows in the DataFrame
print(len(lat_long_df))

# Display the first 5 rows of the DataFrame
lat_long_df
# Out:
# 5
#                         _id   FHRSID  ChangesByServerID  \
# 0  64be8ec1a8ac077a10707cc2  1380578                  0
# 1  64be8ec1a8ac077a10707cee   909912                  0
# 2  64be8ec1a8ac077a10707ceb   694478                  0
# 3  64be8ec1a8ac077a10707ca4   695223                  0
# 4  64be8ec1a8ac077a10707cd2   694609                  0
#
#   LocalAuthorityBusinessID                   BusinessName  \
# 0                    14425  Howe and Co Fish and Chips...
# 1             PI/000201100  Lumbini Grocery Ltd T/A Al...
# 2             PI/000086506              Atlantic Fish Bar
# 3             PI/000178842                        Iceland
# 4             PI/000116619                      Volunteer
#
#                     BusinessType  BusinessTypeID  \
# 0                 Mobile caterer            7846
# 1              Retailers - other            4613
# 2         Takeaway/sandwich shop            7844
# 3  Retailers - supermarkets/h...            7840
# 4              Pub/bar/nightclub            7843
#
#                     AddressLine1 AddressLine2 AddressLine3  ...  \
# 0  Restaurant And Premises 10...                 Plumstead  ...
# 1               17 Lakedale Road                 Plumstead  ...
# 2               35 Lakedale Road                 Plumstead  ...
# 3  144 - 146 Plumstead High S...                 Plumstead  ...
# 4  130 - 132 Plumstead High S...                 Plumstead  ...
#
#            LocalAuthorityWebSite    LocalAuthorityEmailAddress  \
# 0  http://www.royalgreenwich....  health@royalgreenwich.gov.uk
# 1  http://www.royalgreenwich....  health@royalgreenwich.gov.uk
# 2  http://www.royalgreenwich....  health@royalgreenwich.gov.uk
# 3  http://www.royalgreenwich....  health@royalgreenwich.gov.uk
# 4  http://www.royalgreenwich....  health@royalgreenwich.gov.uk
#
#                           scores  SchemeType                        geocode  \
# 0  {'Hygiene': 0, 'Structural...        FHRS  {'longitude': 0.0925370007...
# 1  {'Hygiene': 0, 'Structural...        FHRS  {'longitude': 0.0916256, '...
# 2  {'Hygiene': 0, 'Structural...        FHRS  {'longitude': 0.0912164, '...
# 3  {'Hygiene': 0, 'Structural...        FHRS  {'longitude': 0.0924199968...
# 4  {'Hygiene': 0, 'Structural...        FHRS  {'longitude': 0.09208, 'la...
#
#   RightToReply     Distance NewRatingPending                           meta  \
# 0               4646.955931            False  {'dataSource': None, 'extr...
# 1               4646.975587            False  {'dataSource': None, 'extr...
# 2               4646.974612            False  {'dataSource': None, 'extr...
# 3               4646.946071            False  {'dataSource': None, 'extr...
# 4               4646.965635            False  {'dataSource': None, 'extr...
#
#                            links
# 0  [{'rel': 'self', 'href': '...
# 1  [{'rel': 'self', 'href': '...
# 2  [{'rel': 'self', 'href': '...
# 3  [{'rel': 'self', 'href': '...
# 4  [{'rel': 'self', 'href': '...
#
# [5 rows x 28 columns]

# %% [markdown]
# ### 4. How many establishments in each Local Authority area have a hygiene score of 0?

# %%
# Create a pipeline that: 
# 1. Matches establishments with a hygiene score of 0
# 2. Groups the matches by Local Authority
# 3. Sorts the matches from highest to lowest

match_query = {'$match': {'scores.Hygiene': 20}}

group_query = {'$group': {'_id': "$LocalAuthorityName"}}

sort_values =  {'$sort': { 'score.Hygiene': 1 }}

pipeline = [match_query, group_query, sort_values]

results = list(establishments.aggregate(pipeline))

# Print the number of documents in the result

print("Number of documents in result: ", len(results))

# Print the first 10 results
pprint(results[0:10])
# Out:
# Number of documents in result:  17
# [{'_id': 'Bexley'},
#  {'_id': 'Waltham Forest'},
#  {'_id': 'Tendring'},
#  {'_id': 'Lewes'},
#  {'_id': 'Uttlesford'},
#  {'_id': 'Barking and Dagenham'},
#  {'_id': 'Newham'},
#  {'_id': 'Southend-On-Sea'},
#  {'_id': 'Bromley'},
#  {'_id': 'Havering'}]

# %%
# Convert the result to a Pandas DataFrame

zero_hygiene_df = pd.DataFrame(results)

# Display the number of rows in the DataFrame

print("Rows in DataFrame: ", len(zero_hygiene_df))

# Display the first 10 rows of the DataFrame

zero_hygiene_df.head(10)
# Out:
# Rows in DataFrame:  17
#                     _id
# 0                Bexley
# 1        Waltham Forest
# 2              Tendring
# 3                 Lewes
# 4            Uttlesford
# 5  Barking and Dagenham
# 6                Newham
# 7       Southend-On-Sea
# 8               Bromley
# 9              Havering
