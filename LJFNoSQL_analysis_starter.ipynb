# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Notebook Set Up

# %%
# Import dependencies
from pymongo import MongoClient
import pandas as pd
from pprint import pprint
pd.options.display.max_colwidth = 30

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# assign the uk_food database to a variable name
db = mongo['uk_food']

# %%
# review the collections in our database
print(db.list_collection_names())
# Out:
# ['establishments']

# %%
# assign the collection to a variable
establishments = db['establishments']

# %% [markdown]
# ## Part 3: Exploratory Analysis
# Unless otherwise stated, for each question:
# * Use `count_documents` to display the number of documents contained in the result.
# * Display the first document in the results using `pprint`.
# * Convert the result to a Pandas DataFrame, print the number of rows in the DataFrame, and display the first 10 rows.

# %% [markdown]
# ### 1. Which establishments have a hygiene score equal to 20?

# %%
# Find the establishments with a hygiene score of 20
hygiene_query = {'scores.Hygiene': 20}


# Use count_documents to display the number of documents in the result
# Print the number of results

total_hygiene = establishments.count_documents(hygiene_query)
print("Total documents in result:", total_hygiene)

# Display the first document in the results using pprint

results = list(establishments.find(hygiene_query))
for result in results:
    pprint(result)
# Out:
# Total documents in result: 41
# {'AddressLine1': '5-6 Southfields Road',
#  'AddressLine2': 'Eastbourne',
#  'AddressLine3': 'East Sussex',
#  'AddressLine4': '',
#  'BusinessName': 'The Chase Rest Home',
#  'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  'ChangesByServerID': 0,
#  'Distance': 4613.888288172291,
#  'FHRSID': 110681,
#  'LocalAuthorityBusinessID': '4029',
#  'LocalAuthorityCode': '102',
#  'LocalAuthorityEmailAddress': 'Customerfirst@eastbourne.gov.uk',
#  'LocalAuthorityName': 'Eastbourne',
#  'LocalAuthorityWebSite': 'http://www.eastbourne.gov.uk/foodratings',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'BN21 1BU',
#  'RatingDate': '2021-09-23T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': 0,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64be8ec0a8ac077a10702472'),
#  'geocode': {'latitude': Decimal128('50.769705'),
#              'longitude': Decimal128('0.27694')},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/110681',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 20, 'Structural': 20}}
# {'AddressLine1': 'Hall Lane',
#  'AddressLine2': 'Walton-on-the-Naze',
#  'AddressLine3': 'Essex',
#  'AddressLine4': '',
#  'BusinessName': 'Brenalwood',
#  'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  'ChangesByServerID': 0,
#  'Distance': 4617.965823673803,
#  'FHRSID': 612039,
#  'LocalAuthorityBusinessID': '1970/FOOD',
#  'LocalAuthorityCode': '120',
#  'LocalAuthorityEmailAddress': 'fhsadmin@tendringdc.gov.uk',
#  'LocalAuthorityName': 'Tendring',
#  'LocalAuthorityWebSite': 'http://www.tendringdc.gov.uk/',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CO14 8HN',
#  'RatingDate': '2022-06-22T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': 0,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64be8ec0a8ac077a107027f8'),
#  'geocode': {'latitude': Decimal128('51.857536'),
#              'longitude': Decimal128('1.278721')},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/612039',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 30, 'Hygiene': 20, 'Structural': 15}}
# {'AddressLine1': '53 Marine Parade East',
#  'AddressLine2': 'Clacton On Sea',
#  'AddressLine3': 'Essex',
#  'AddressLine4': '',
#  'BusinessName': 'Melrose Hotel',
#  'BusinessType': 'Hotel/bed & breakfast/guest house',
#  'BusinessTypeID': 7842,
#  'ChangesByServerID': 0,
#  'Distance': 4619.6561440278165,
#  'FHRSID': 730933,
#  'LocalAuthorityBusinessID': '1698/FOOD',
#  'LocalAuthorityCode': '120',
#  'LocalAuthorityEmailAddress': 'fhsadmin@tendringdc.gov.uk',
#  'LocalAuthorityName': 'Tendring',
#  'LocalAuthorityWebSite': 'http://www.tendringdc.gov.uk/',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CO15 6AD',
#  'RatingDate': '2021-08-13T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': 0,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64be8ec0a8ac077a10702b00'),
#  'geocode': {'latitude': Decimal128('51.789429'),
#              'longitude': Decimal128('1.15927')},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/730933',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 20, 'Structural': 20}}
# {'AddressLine1': '4 High Street',
#  'AddressLine2': 'Seaford',
#  'AddressLine3': 'East Sussex',
#  'AddressLine4': '',
#  'BusinessName': 'Seaford Pizza',
#  'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  'ChangesByServerID': 0,
#  'Distance': 4620.421724673841,
#  'FHRSID': 172735,
#  'LocalAuthorityBusinessID': 'PI/000023858',
#  'LocalAuthorityCode': '105',
#  'LocalAuthorityEmailAddress': 'ehealth.ldc@lewes-eastbourne.gov.uk',
#  'LocalAuthorityName': 'Lewes',
#  'LocalAuthorityWebSite': 'http://www.lewes-eastbourne.gov.uk/',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'BN25 1PG',
#  'RatingDate': '2021-12-23T00:00:00',
#  'RatingKey': 'fhrs_1_en-gb',
#  'RatingValue': 1,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64be8ec0a8ac077a10702cf0'),
#  'geocode': {'latitude': Decimal128('50.770885'),
#              'longitude': Decimal128('0.10202')},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/172735',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 20, 'Structural': 10}}
# {'AddressLine1': '5 South Street',
#  'AddressLine2': 'Seaford',
#  'AddressLine3': 'East Sussex',
#  'AddressLine4': '',
#  'BusinessName': 'Golden Palace',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4620.437179097401,
#  'FHRSID': 172953,
#  'LocalAuthorityBusinessID': 'PI/000024532',
#  'LocalAuthorityCode': '105',
#  'LocalAuthorityEmailAddress': 'ehealth.ldc@lewes-eastbourne.gov.uk',
#  'LocalAuthorityName': 'Lewes',
#  'LocalAuthorityWebSite': 'http://www.lewes-eastbourne.gov.uk/',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'BN25 1HP',
#  'RatingDate': '2021-10-07T00:00:00',
#  'RatingKey': 'fhrs_1_en-gb',
#  'RatingValue': 1,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64be8ec0a8ac077a10702cfb'),
#  'geocode': {'latitude': Decimal128('50.770724'),
#              'longitude': Decimal128('0.101446')},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/172953',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 20, 'Structural': 10}}
# {'AddressLine1': '777 Southchurch Road',
#  'AddressLine2': 'Southend-On-Sea',
#  'AddressLine3': 'Essex',
#  'AddressLine4': '',
#  'BusinessName': "Ashby's Butchers",
#  'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  'ChangesByServerID': 0,
#  'Distance': 4625.565258384611,
#  'FHRSID': 512854,
#  'LocalAuthorityBusinessID': '12/00816/BUTH',
#  'LocalAuthorityCode': '893',
#  'LocalAuthorityEmailAddress': 'EnvironmentalHealth@southend.gov.uk',
#  'LocalAuthorityName': 'Southend-On-Sea',
#  'LocalAuthorityWebSite': 'http://www.southend.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'SS1 2PP',
#  'RatingDate': '2022-07-21T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': 0,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64be8ec0a8ac077a10703699'),
#  'geocode': {'latitude': Decimal128('51.541448'),
#              'longitude': Decimal128('0.736349')},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/512854',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 20, 'Structural': 20}}
# {'AddressLine1': '33 Alexandra Street',
#  'AddressLine2': 'Southend-on-sea',
#  'AddressLine3': 'Essex',
#  'AddressLine4': '',
#  'BusinessName': 'South Sea Express Cuisine',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4626.200132034163,
#  'FHRSID': 1537089,
#  'LocalAuthorityBusinessID': '22/00224/RESTUN',
#  'LocalAuthorityCode': '893',
#  'LocalAuthorityEmailAddress': 'EnvironmentalHealth@southend.gov.uk',
#  'LocalAuthorityName': 'Southend-On-Sea',
#  'LocalAuthorityWebSite': 'http://www.southend.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'SS1 1BW',
#  'RatingDate': '2022-08-03T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': 0,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64be8ec0a8ac077a107038c1'),
#  'geocode': {'latitude': Decimal128('51.5350065'),
#              'longitude': Decimal128('0.7121671')},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/1537089',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 20, 'Structural': 20}}
# {'AddressLine1': '7 London Road',
#  'AddressLine2': 'Rayleigh',
#  'AddressLine3': 'Essex',
#  'AddressLine4': '',
#  'BusinessName': 'Golden Palace',
#  'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  'ChangesByServerID': 0,
#  'Distance': 4632.27689004769,
#  'FHRSID': 155648,
#  'LocalAuthorityBusinessID': 'EH/00006058',
#  'LocalAuthorityCode': '118',
#  'LocalAuthorityEmailAddress': 'customerservices@rochford.gov.uk',
#  'LocalAuthorityName': 'Rochford',
#  'LocalAuthorityWebSite': 'http://www.rochford.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'SS6 9HN',
#  'RatingDate': '2022-03-23T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': 0,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64be8ec0a8ac077a10704de8'),
#  'geocode': {'latitude': Decimal128('51.591515'),
#              'longitude': Decimal128('0.602364')},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/155648',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 30, 'Hygiene': 20, 'Structural': 15}}
# {'AddressLine1': '3 The Village',
#  'AddressLine2': 'Chiddingstone',
#  'AddressLine3': 'KENT',
#  'AddressLine4': '',
#  'BusinessName': 'The Tulip Tree',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4633.934040834287,
#  'FHRSID': 1012883,
#  'LocalAuthorityBusinessID': '17/00110/MIXED/S',
#  'LocalAuthorityCode': '187',
#  'LocalAuthorityEmailAddress': 'environmental.health@sevenoaks.gov.uk',
#  'LocalAuthorityName': 'Sevenoaks',
#  'LocalAuthorityWebSite': 'http://www.sevenoaks.gov.uk/',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'TN8 7AH',
#  'RatingDate': '2022-03-04T00:00:00',
#  'RatingKey': 'fhrs_1_en-gb',
#  'RatingValue': 1,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64be8ec0a8ac077a10705231'),
#  'geocode': {'latitude': Decimal128('51.1859474182129'),
#              'longitude': Decimal128('0.146449998021126')},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1012883',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 20, 'Structural': 5}}
# {'AddressLine1': '',
#  'AddressLine2': '81 Southernhay',
#  'AddressLine3': 'Basildon',
#  'AddressLine4': 'Essex',
#  'BusinessName': 'F & S',
#  'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  'ChangesByServerID': 0,
#  'Distance': 4636.552523353182,
#  'FHRSID': 644109,
#  'LocalAuthorityBusinessID': '41811',
#  'LocalAuthorityCode': '109',
#  'LocalAuthorityEmailAddress': 'ehs@basildon.gov.uk',
#  'LocalAuthorityName': 'Basildon',
#  'LocalAuthorityWebSite': 'http://www.basildon.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'SS14 1EU',
#  'RatingDate': '2021-07-26T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': 0,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64be8ec0a8ac077a10705a41'),
#  'geocode': {'latitude': Decimal128('51.57005'),
#              'longitude': Decimal128('0.462307')},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/644109',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 20, 'Structural': 20}}
# {'AddressLine1': '17 London Road',
#  'AddressLine2': 'Riverhead',
#  'AddressLine3': 'KENT',
#  'AddressLine4': '',
#  'BusinessName': 'Longhouse',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4636.703065274148,
#  'FHRSID': 267034,
#  'LocalAuthorityBusinessID': '11/00102/MIXED',
#  'LocalAuthorityCode': '187',
#  'LocalAuthorityEmailAddress': 'environmental.health@sevenoaks.gov.uk',
#  'LocalAuthorityName': 'Sevenoaks',
#  'LocalAuthorityWebSite': 'http://www.sevenoaks.gov.uk/',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'TN13 2BU',
#  'RatingDate': '2022-07-27T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': 0,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64be8ec0a8ac077a10705aaf'),
#  'geocode': {'latitude': Decimal128('51.284795'),
#              'longitude': Decimal128('0.169685')},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/267034',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 30, 'Hygiene': 20, 'Structural': 25}}
# {'AddressLine1': 'Downsview Community Primary School',
#  'AddressLine2': 'Beech Avenue',
#  'AddressLine3': 'Swanley',
#  'AddressLine4': 'KENT',
#  'BusinessName': 'Westview Playgroup Based At Downsview Comm Primary',
#  'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  'ChangesByServerID': 0,
#  'Distance': 4640.152449114619,
#  'FHRSID': 972876,
#  'LocalAuthorityBusinessID': '17/00059/FOOD/S',
#  'LocalAuthorityCode': '187',
#  'LocalAuthorityEmailAddress': 'environmental.health@sevenoaks.gov.uk',
#  'LocalAuthorityName': 'Sevenoaks',
#  'LocalAuthorityWebSite': 'http://www.sevenoaks.gov.uk/',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'BR8 8AU',
#  'RatingDate': '2022-03-16T00:00:00',
#  'RatingKey': 'fhrs_1_en-gb',
#  'RatingValue': 1,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64be8ec0a8ac077a10706162'),
#  'geocode': {'latitude': Decimal128('51.3954686'),
#              'longitude': Decimal128('0.1864034')},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/972876',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 20, 'Structural': 20}}
# {'AddressLine1': 'EMR Erith',
#  'AddressLine2': 'Manor Road',
#  'AddressLine3': 'Erith',
#  'AddressLine4': 'Kent',
#  'BusinessName': 'Whatever The Weather Coffee',
#  'BusinessType': 'Mobile caterer',
#  'BusinessTypeID': 7846,
#  'ChangesByServerID': 0,
#  'Distance': 4642.935252133844,
#  'FHRSID': 1417416,
#  'LocalAuthorityBusinessID': '21/00350/CP',
#  'LocalAuthorityCode': '503',
#  'LocalAuthorityEmailAddress': 'food.safety@bexley.gov.uk',
#  'LocalAuthorityName': 'Bexley',
#  'LocalAuthorityWebSite': 'http://www.bexley.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'DA8 2AD',
#  'RatingDate': '2022-02-17T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': 0,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64be8ec0a8ac077a10706a2e'),
#  'geocode': {'latitude': Decimal128('51.4774259502039'),
#              'longitude': Decimal128('0.19265740017645')},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1417416',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 20, 'Structural': 15}}
# {'AddressLine1': '43 Kings Road',
#  'AddressLine2': 'Brentwood',
#  'AddressLine3': 'Essex',
#  'AddressLine4': '',
#  'BusinessName': 'Kings Restaurant (Oriental)',
#  'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  'ChangesByServerID': 0,
#  'Distance': 4644.277277495872,
#  'FHRSID': 1384371,
#  'LocalAuthorityBusinessID': '21/00062/MIXED',
#  'LocalAuthorityCode': '111',
#  'LocalAuthorityEmailAddress': 'envhealth@brentwood.gov.uk',
#  'LocalAuthorityName': 'Brentwood',
#  'LocalAuthorityWebSite': 'http://www.brentwood.gov.uk/',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CM14 4DJ',
#  'RatingDate': '2022-07-05T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': 0,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64be8ec1a8ac077a1070703d'),
#  'geocode': {'latitude': Decimal128('51.618135'),
#              'longitude': Decimal128('0.2983')},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1384371',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 20, 'Structural': 25}}
# {'AddressLine1': '24 Station Lane',
#  'AddressLine2': 'Hornchurch',
#  'AddressLine3': '',
#  'AddressLine4': '',
#  'BusinessName': 'Xich Lo',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4645.006441020867,
#  'FHRSID': 907216,
#  'LocalAuthorityBusinessID': '132648',
#  'LocalAuthorityCode': '516',
#  'LocalAuthorityEmailAddress': 'environmental.health@havering.gov.uk',
#  'LocalAuthorityName': 'Havering',
#  'LocalAuthorityWebSite': 'http://www.havering.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'RM12 6NJ',
#  'RatingDate': '2022-07-15T00:00:00',
#  'RatingKey': 'fhrs_1_en-gb',
#  'RatingValue': 1,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64be8ec1a8ac077a107073a0'),
#  'geocode': {'latitude': Decimal128('51.561287'),
#              'longitude': Decimal128('0.220507')},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/907216',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 10, 'Hygiene': 20, 'Structural': 5}}
# {'AddressLine1': '2 - 6 Basildon Road',
#  'AddressLine2': '',
#  'AddressLine3': 'Abbey Wood',
#  'AddressLine4': 'Greenwich',
#  'BusinessName': 'Asian Supermarket Ltd: T/A Best Food Wine Ltd',
#  'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  'ChangesByServerID': 0,
#  'Distance': 4646.327124710291,
#  'FHRSID': 710382,
#  'LocalAuthorityBusinessID': 'PI/000194267',
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': '',
#  'RatingDate': '2022-04-22T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': 0,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64be8ec1a8ac077a1070790c'),
#  'geocode': {'latitude': Decimal128('51.4848146'),
#              'longitude': Decimal128('0.1070469')},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/710382',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 20, 'Structural': 20}}
# {'AddressLine1': '5 - 7 Cranley Parade',
#  'AddressLine2': 'Beaconsfield Road',
#  'AddressLine3': 'Mottingham',
#  'AddressLine4': 'London',
#  'BusinessName': 'Londis',
#  'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  'ChangesByServerID': 0,
#  'Distance': 4646.4482563738065,
#  'FHRSID': 1411729,
#  'LocalAuthorityBusinessID': '21/00562/MIXED',
#  'LocalAuthorityCode': '505',
#  'LocalAuthorityEmailAddress': 'food@bromley.gov.uk',
#  'LocalAuthorityName': 'Bromley',
#  'LocalAuthorityWebSite': 'http://www.bromley.gov.uk',
#  'NewRatingPending': True,
#  'Phone': '',
#  'PostCode': 'SE9 4DZ',
#  'RatingDate': '2021-11-12T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': 0,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64be8ec1a8ac077a1070797c'),
#  'geocode': {'latitude': Decimal128('51.4273993'),
#              'longitude': Decimal128('0.0460971')},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1411729',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 30, 'Hygiene': 20, 'Structural': 10}}
# {'AddressLine1': '2 The Slade',
#  'AddressLine2': '',
#  'AddressLine3': 'Plumstead',
#  'AddressLine4': 'Greenwich',
#  'BusinessName': 'Costcutter',
#  'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  'ChangesByServerID': 0,
#  'Distance': 4646.814121604596,
#  'FHRSID': 1060293,
#  'LocalAuthorityBusinessID': 'PI/000206588',
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'SE18 2NB',
#  'RatingDate': '2022-03-14T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': 0,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64be8ec1a8ac077a10707be5'),
#  'geocode': {'latitude': Decimal128('51.4800266'),
#              'longitude': Decimal128('0.0888789')},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1060293',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 20, 'Structural': 15}}
# {'AddressLine1': '',
#  'AddressLine2': '8 Porters Avenue',
#  'AddressLine3': '',
#  'AddressLine4': 'Dagenham',
#  'BusinessName': 'La Simon Ltd',
#  'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  'ChangesByServerID': 0,
#  'Distance': 4647.937954737693,
#  'FHRSID': 1243155,
#  'LocalAuthorityBusinessID': '75460',
#  'LocalAuthorityCode': '501',
#  'LocalAuthorityEmailAddress': 'foodsafety@lbbd.gov.uk',
#  'LocalAuthorityName': 'Barking and Dagenham',
#  'LocalAuthorityWebSite': 'http://www.lbbd.gov.uk/Pages/Home.aspx',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'RM8 2AQ',
#  'RatingDate': '2022-03-30T00:00:00',
#  'RatingKey': 'fhrs_1_en-gb',
#  'RatingValue': 1,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64be8ec1a8ac077a107081bb'),
#  'geocode': {'latitude': Decimal128('51.5515791'),
#              'longitude': Decimal128('0.1300921')},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1243155',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 20, 'Structural': 15}}
# {'AddressLine1': '',
#  'AddressLine2': '87 Longbridge Road',
#  'AddressLine3': '',
#  'AddressLine4': 'Barking',
#  'BusinessName': 'Caribiscus Ltd',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4649.2374619583225,
#  'FHRSID': 1210197,
#  'LocalAuthorityBusinessID': '75196',
#  'LocalAuthorityCode': '501',
#  'LocalAuthorityEmailAddress': 'foodsafety@lbbd.gov.uk',
#  'LocalAuthorityName': 'Barking and Dagenham',
#  'LocalAuthorityWebSite': 'http://www.lbbd.gov.uk/Pages/Home.aspx',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'IG11 8TB',
#  'RatingDate': '2022-06-20T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': 0,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64be8ec1a8ac077a1070877c'),
#  'geocode': {'latitude': Decimal128('51.541715'),
#              'longitude': Decimal128('0.084452')},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1210197',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 30, 'Hygiene': 20, 'Structural': 20}}
# {'AddressLine1': '',
#  'AddressLine2': '66 Station Parade',
#  'AddressLine3': '',
#  'AddressLine4': 'Barking',
#  'BusinessName': 'Kennedy Fried Chicken',
#  'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  'ChangesByServerID': 0,
#  'Distance': 4649.2519200445495,
#  'FHRSID': 108663,
#  'LocalAuthorityBusinessID': '38915',
#  'LocalAuthorityCode': '501',
#  'LocalAuthorityEmailAddress': 'foodsafety@lbbd.gov.uk',
#  'LocalAuthorityName': 'Barking and Dagenham',
#  'LocalAuthorityWebSite': 'http://www.lbbd.gov.uk/Pages/Home.aspx',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'IG11 8EA',
#  'RatingDate': '2022-06-11T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': 0,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64be8ec1a8ac077a1070878f'),
#  'geocode': {'latitude': Decimal128('51.539293'),
#              'longitude': Decimal128('0.081616')},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/108663',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 30, 'Hygiene': 20, 'Structural': 20}}
# {'AddressLine1': '5 High Street South',
#  'AddressLine2': 'East Ham',
#  'AddressLine3': 'London',
#  'AddressLine4': '',
#  'BusinessName': 'Gah Shing',
#  'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  'ChangesByServerID': 0,
#  'Distance': 4649.903793551815,
#  'FHRSID': 1107748,
#  'LocalAuthorityBusinessID': '19/00222/FOOD',
#  'LocalAuthorityCode': '525',
#  'LocalAuthorityEmailAddress': 'food@newham.gov.uk',
#  'LocalAuthorityName': 'Newham',
#  'LocalAuthorityWebSite': 'https://www.newham.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'E6 6EN',
#  'RatingDate': '2022-05-11T00:00:00',
#  'RatingKey': 'fhrs_1_en-gb',
#  'RatingValue': 1,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64be8ec1a8ac077a10708a5c'),
#  'geocode': {'latitude': Decimal128('51.531385'),
#              'longitude': Decimal128('0.055764')},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1107748',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 10, 'Hygiene': 20, 'Structural': 15}}
# {'AddressLine1': '',
#  'AddressLine2': '221 Ilford Lane',
#  'AddressLine3': '',
#  'AddressLine4': 'Ilford',
#  'BusinessName': 'A1 News & Wine',
#  'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  'ChangesByServerID': 0,
#  'Distance': 4649.968842000992,
#  'FHRSID': 570096,
#  'LocalAuthorityBusinessID': '178447',
#  'LocalAuthorityCode': '526',
#  'LocalAuthorityEmailAddress': 'themis.skouros@redbridge.gov.uk',
#  'LocalAuthorityName': 'Redbridge',
#  'LocalAuthorityWebSite': 'http://www.redbridge.gov.uk/',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'IG1 2RZ',
#  'RatingDate': '2021-06-02T00:00:00',
#  'RatingKey': 'fhrs_1_en-gb',
#  'RatingValue': 1,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64be8ec1a8ac077a10708a9f'),
#  'geocode': {'latitude': Decimal128('51.551624'),
#              'longitude': Decimal128('0.074347')},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/570096',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 20, 'Structural': 10}}
# {'AddressLine1': '',
#  'AddressLine2': '108 Ilford Lane',
#  'AddressLine3': '',
#  'AddressLine4': 'Ilford',
#  'BusinessName': 'Cakes & Bakes',
#  'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  'ChangesByServerID': 0,
#  'Distance': 4650.123644180097,
#  'FHRSID': 1500698,
#  'LocalAuthorityBusinessID': '201759',
#  'LocalAuthorityCode': '526',
#  'LocalAuthorityEmailAddress': 'themis.skouros@redbridge.gov.uk',
#  'LocalAuthorityName': 'Redbridge',
#  'LocalAuthorityWebSite': 'http://www.redbridge.gov.uk/',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'IG1 2LD',
#  'RatingDate': '2022-05-19T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': 0,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64be8ec1a8ac077a10708bbd'),
#  'geocode': {'latitude': Decimal128('51.5540755'),
#              'longitude': Decimal128('0.0725645')},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1500698',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 20, 'Structural': 15}}
# {'AddressLine1': '',
#  'AddressLine2': '149 Ley Street',
#  'AddressLine3': '',
#  'AddressLine4': 'Ilford',
#  'BusinessName': 'Sahajanand Catering Limited',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4650.2394323606195,
#  'FHRSID': 1318114,
#  'LocalAuthorityBusinessID': '200845',
#  'LocalAuthorityCode': '526',
#  'LocalAuthorityEmailAddress': 'themis.skouros@redbridge.gov.uk',
#  'LocalAuthorityName': 'Redbridge',
#  'LocalAuthorityWebSite': 'http://www.redbridge.gov.uk/',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'IG1 4BL',
#  'RatingDate': '2022-07-04T00:00:00',
#  'RatingKey': 'fhrs_1_en-gb',
#  'RatingValue': 1,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64be8ec1a8ac077a10708c6b'),
#  'geocode': {'latitude': Decimal128('51.562276'),
#              'longitude': Decimal128('0.077645')},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1318114',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 20, 'Structural': 20}}
# {'AddressLine1': '151 - 153 Barking Road',
#  'AddressLine2': 'East Ham',
#  'AddressLine3': 'London',
#  'AddressLine4': '',
#  'BusinessName': 'Sisko Cafe',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4650.247785381525,
#  'FHRSID': 1498084,
#  'LocalAuthorityBusinessID': '22/00797/FOOD',
#  'LocalAuthorityCode': '525',
#  'LocalAuthorityEmailAddress': 'food@newham.gov.uk',
#  'LocalAuthorityName': 'Newham',
#  'LocalAuthorityWebSite': 'https://www.newham.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'E6 1LD',
#  'RatingDate': '2022-04-22T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': 0,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64be8ec1a8ac077a10708c7a'),
#  'geocode': {'latitude': Decimal128('51.531936'),
#              'longitude': Decimal128('0.046878')},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1498084',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 20, 'Structural': 20}}
# {'AddressLine1': '221 High Street North',
#  'AddressLine2': 'East Ham',
#  'AddressLine3': 'London',
#  'AddressLine4': '',
#  'BusinessName': 'Magazin Romanesc Diana',
#  'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  'ChangesByServerID': 0,
#  'Distance': 4650.389970646722,
#  'FHRSID': 1063454,
#  'LocalAuthorityBusinessID': '18/00285/FOOD',
#  'LocalAuthorityCode': '525',
#  'LocalAuthorityEmailAddress': 'food@newham.gov.uk',
#  'LocalAuthorityName': 'Newham',
#  'LocalAuthorityWebSite': 'https://www.newham.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'E6 1JG',
#  'RatingDate': '2022-07-25T00:00:00',
#  'RatingKey': 'fhrs_1_en-gb',
#  'RatingValue': 1,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64be8ec1a8ac077a10708d67'),
#  'geocode': {'latitude': Decimal128('51.53963'),
#              'longitude': Decimal128('0.050713')},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1063454',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 20, 'Structural': 10}}
# {'AddressLine1': '241B High Street North',
#  'AddressLine2': 'Manor Park',
#  'AddressLine3': 'London',
#  'AddressLine4': '',
#  'BusinessName': 'Bali Maamalas',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4650.459698178172,
#  'FHRSID': 1130121,
#  'LocalAuthorityBusinessID': '19/00249/FOOD',
#  'LocalAuthorityCode': '525',
#  'LocalAuthorityEmailAddress': 'food@newham.gov.uk',
#  'LocalAuthorityName': 'Newham',
#  'LocalAuthorityWebSite': 'https://www.newham.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'E12 6SJ',
#  'RatingDate': '2022-05-11T00:00:00',
#  'RatingKey': 'fhrs_1_en-gb',
#  'RatingValue': 1,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64be8ec1a8ac077a10708dde'),
#  'geocode': {'latitude': Decimal128('51.541156'),
#              'longitude': Decimal128('0.050334')},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1130121',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 20, 'Structural': 10}}
# {'AddressLine1': '333 Barking Road',
#  'AddressLine2': 'Plaistow',
#  'AddressLine3': 'London',
#  'AddressLine4': '',
#  'BusinessName': 'Angels Bakery',
#  'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  'ChangesByServerID': 0,
#  'Distance': 4650.822100156243,
#  'FHRSID': 640363,
#  'LocalAuthorityBusinessID': '10/00269/FOOD',
#  'LocalAuthorityCode': '525',
#  'LocalAuthorityEmailAddress': 'food@newham.gov.uk',
#  'LocalAuthorityName': 'Newham',
#  'LocalAuthorityWebSite': 'https://www.newham.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'E13 8EE',
#  'RatingDate': '2022-07-20T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': 0,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64be8ec1a8ac077a10709025'),
#  'geocode': {'latitude': Decimal128('51.52189'),
#              'longitude': Decimal128('0.021028')},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/640363',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 20, 'Structural': 20}}
# {'AddressLine1': '282 Barking Road',
#  'AddressLine2': 'Plaistow',
#  'AddressLine3': 'London',
#  'AddressLine4': '',
#  'BusinessName': 'Nikkis Place Restaurant',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4650.85622582084,
#  'FHRSID': 640816,
#  'LocalAuthorityBusinessID': '61130/0282/0/000',
#  'LocalAuthorityCode': '525',
#  'LocalAuthorityEmailAddress': 'food@newham.gov.uk',
#  'LocalAuthorityName': 'Newham',
#  'LocalAuthorityWebSite': 'https://www.newham.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'E13 8HR',
#  'RatingDate': '2022-06-30T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': 0,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64be8ec1a8ac077a10709078'),
#  'geocode': {'latitude': Decimal128('51.520147'),
#              'longitude': Decimal128('0.018342')},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/640816',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 20, 'Structural': 20}}
# {'AddressLine1': '369 Katherine Road',
#  'AddressLine2': 'Forest Gate',
#  'AddressLine3': 'London',
#  'AddressLine4': '',
#  'BusinessName': 'Chicago 30',
#  'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  'ChangesByServerID': 0,
#  'Distance': 4650.9448351911105,
#  'FHRSID': 1530599,
#  'LocalAuthorityBusinessID': '22/01037/FOOD',
#  'LocalAuthorityCode': '525',
#  'LocalAuthorityEmailAddress': 'food@newham.gov.uk',
#  'LocalAuthorityName': 'Newham',
#  'LocalAuthorityWebSite': 'https://www.newham.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'E7 8LT',
#  'RatingDate': '2022-07-05T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': 0,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64be8ec1a8ac077a107090e6'),
#  'geocode': {'latitude': Decimal128('51.541658'),
#              'longitude': Decimal128('0.037523')},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1530599',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 30, 'Hygiene': 20, 'Structural': 15}}
# {'AddressLine1': 'The Kinema',
#  'AddressLine2': 'Chelmsford Road',
#  'AddressLine3': 'Dunmow',
#  'AddressLine4': '',
#  'BusinessName': 'Samui Thai Restaurant',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4651.0999945416315,
#  'FHRSID': 668674,
#  'LocalAuthorityBusinessID': '14/00082/COM',
#  'LocalAuthorityCode': '122',
#  'LocalAuthorityEmailAddress': 'environmentalhealth@uttlesford.gov.uk',
#  'LocalAuthorityName': 'Uttlesford',
#  'LocalAuthorityWebSite': 'http://www.uttlesford.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CM6 1HB',
#  'RatingDate': '2022-03-24T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': 0,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64be8ec1a8ac077a107091ee'),
#  'geocode': {'latitude': Decimal128('51.8686712'),
#              'longitude': Decimal128('0.3659018')},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/668674',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 30, 'Hygiene': 20, 'Structural': 20}}
# {'AddressLine1': '76 Green Street',
#  'AddressLine2': 'Forest Gate',
#  'AddressLine3': 'London',
#  'AddressLine4': '',
#  'BusinessName': 'Pakhtoonkhwa Restaurant',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4651.2331297369665,
#  'FHRSID': 1286585,
#  'LocalAuthorityBusinessID': '20/00532/FOOD',
#  'LocalAuthorityCode': '525',
#  'LocalAuthorityEmailAddress': 'food@newham.gov.uk',
#  'LocalAuthorityName': 'Newham',
#  'LocalAuthorityWebSite': 'https://www.newham.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'E7 8JG',
#  'RatingDate': '2022-06-14T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': 0,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64be8ec1a8ac077a107092dc'),
#  'geocode': {'latitude': Decimal128('51.543994'),
#              'longitude': Decimal128('0.031959')},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1286585',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 20, 'Structural': 20}}
# {'AddressLine1': '23 Stortford Road',
#  'AddressLine2': 'Dunmow',
#  'AddressLine3': '',
#  'AddressLine4': '',
#  'BusinessName': 'New Happy Garden',
#  'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  'ChangesByServerID': 0,
#  'Distance': 4651.44448783849,
#  'FHRSID': 971735,
#  'LocalAuthorityBusinessID': '17/00076/COM',
#  'LocalAuthorityCode': '122',
#  'LocalAuthorityEmailAddress': 'environmentalhealth@uttlesford.gov.uk',
#  'LocalAuthorityName': 'Uttlesford',
#  'LocalAuthorityWebSite': 'http://www.uttlesford.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CM6 1DA',
#  'RatingDate': '2022-03-28T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': 0,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64be8ec1a8ac077a10709399'),
#  'geocode': {'latitude': Decimal128('51.873055'),
#              'longitude': Decimal128('0.360846')},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/971735',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 20, 'Structural': 20}}
# {'AddressLine1': '34 West Ham Lane',
#  'AddressLine2': 'Stratford',
#  'AddressLine3': 'London',
#  'AddressLine4': '',
#  'BusinessName': 'Mummy Yum',
#  'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  'ChangesByServerID': 0,
#  'Distance': 4652.049759667773,
#  'FHRSID': 1055935,
#  'LocalAuthorityBusinessID': '18/00198/FOOD',
#  'LocalAuthorityCode': '525',
#  'LocalAuthorityEmailAddress': 'food@newham.gov.uk',
#  'LocalAuthorityName': 'Newham',
#  'LocalAuthorityWebSite': 'https://www.newham.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'E15 4SA',
#  'RatingDate': '2022-07-12T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': 0,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64be8ec1a8ac077a10709533'),
#  'geocode': {'latitude': Decimal128('51.538857'),
#              'longitude': Decimal128('0.004389')},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1055935',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 20, 'Structural': 20}}
# {'AddressLine1': '',
#  'AddressLine2': '345 High Road Leytonstone',
#  'AddressLine3': '',
#  'AddressLine4': 'Leytonstone',
#  'BusinessName': 'Gospodina',
#  'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  'ChangesByServerID': 0,
#  'Distance': 4652.63219028813,
#  'FHRSID': 1177878,
#  'LocalAuthorityBusinessID': '347294',
#  'LocalAuthorityCode': '531',
#  'LocalAuthorityEmailAddress': 'environmentalhealth@walthamforest.gov.uk',
#  'LocalAuthorityName': 'Waltham Forest',
#  'LocalAuthorityWebSite': 'http://www.walthamforest.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'E11 4JT',
#  'RatingDate': '2022-06-27T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': 0,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64be8ec1a8ac077a107096c1'),
#  'geocode': {'latitude': Decimal128('51.555782'),
#              'longitude': Decimal128('0.005407')},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1177878',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 30, 'Hygiene': 20, 'Structural': 20}}
# {'AddressLine1': '',
#  'AddressLine2': '32 Church Lane',
#  'AddressLine3': '',
#  'AddressLine4': 'Leytonstone',
#  'BusinessName': "Leo's Bar & Grill",
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4652.953922367066,
#  'FHRSID': 1296829,
#  'LocalAuthorityBusinessID': '347449',
#  'LocalAuthorityCode': '531',
#  'LocalAuthorityEmailAddress': 'environmentalhealth@walthamforest.gov.uk',
#  'LocalAuthorityName': 'Waltham Forest',
#  'LocalAuthorityWebSite': 'http://www.walthamforest.gov.uk',
#  'NewRatingPending': True,
#  'Phone': '',
#  'PostCode': 'E11 1HG',
#  'RatingDate': '2022-06-15T00:00:00',
#  'RatingKey': 'fhrs_1_en-gb',
#  'RatingValue': 1,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64be8ec1a8ac077a107097bc'),
#  'geocode': {'latitude': Decimal128('51.568245'),
#              'longitude': Decimal128('0.009101')},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1296829',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 20, 'Structural': 5}}
# {'AddressLine1': '',
#  'AddressLine2': '14 Hatch Lane',
#  'AddressLine3': '',
#  'AddressLine4': 'Chingford',
#  'BusinessName': 'Royal Ribs',
#  'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  'ChangesByServerID': 0,
#  'Distance': 4654.920995700347,
#  'FHRSID': 514573,
#  'LocalAuthorityBusinessID': '44243',
#  'LocalAuthorityCode': '531',
#  'LocalAuthorityEmailAddress': 'environmentalhealth@walthamforest.gov.uk',
#  'LocalAuthorityName': 'Waltham Forest',
#  'LocalAuthorityWebSite': 'http://www.walthamforest.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'E4 6LQ',
#  'RatingDate': '2022-07-01T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': 0,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64be8ec1a8ac077a10709b24'),
#  'geocode': {'latitude': Decimal128('51.61912'),
#              'longitude': Decimal128('0.006248')},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/514573',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 30, 'Hygiene': 20, 'Structural': 15}}
# {'AddressLine1': 'Great Hallingbury Manor',
#  'AddressLine2': 'Tilekiln Green',
#  'AddressLine3': 'Great Hallingbury',
#  'AddressLine4': 'Bishops Stortford',
#  'BusinessName': 'Great Hallingbury Manor Hotel',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4656.798774391753,
#  'FHRSID': 124507,
#  'LocalAuthorityBusinessID': '53022999151',
#  'LocalAuthorityCode': '122',
#  'LocalAuthorityEmailAddress': 'environmentalhealth@uttlesford.gov.uk',
#  'LocalAuthorityName': 'Uttlesford',
#  'LocalAuthorityWebSite': 'http://www.uttlesford.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CM22 7TJ',
#  'RatingDate': '2021-07-28T00:00:00',
#  'RatingKey': 'fhrs_1_en-gb',
#  'RatingValue': 1,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64be8ec1a8ac077a10709d1d'),
#  'geocode': {'latitude': Decimal128('51.8686828613281'),
#              'longitude': Decimal128('0.207771003246307')},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/124507',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 20, 'Structural': 10}}
# {'AddressLine1': '58 Lower Street',
#  'AddressLine2': 'Stansted',
#  'AddressLine3': 'Essex',
#  'AddressLine4': '',
#  'BusinessName': 'The Dog And Duck',
#  'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  'ChangesByServerID': 0,
#  'Distance': 4658.344880326824,
#  'FHRSID': 479001,
#  'LocalAuthorityBusinessID': '12/00162/COM',
#  'LocalAuthorityCode': '122',
#  'LocalAuthorityEmailAddress': 'environmentalhealth@uttlesford.gov.uk',
#  'LocalAuthorityName': 'Uttlesford',
#  'LocalAuthorityWebSite': 'http://www.uttlesford.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CM24 8LR',
#  'RatingDate': '2021-11-11T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': 0,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64be8ec1a8ac077a10709f38'),
#  'geocode': {'latitude': Decimal128('51.904039'),
#              'longitude': Decimal128('0.201087')},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/479001',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 20, 'Structural': 15}}
# {'AddressLine1': '1 Mercers Row',
#  'AddressLine2': 'Saffron Walden',
#  'AddressLine3': 'Essex',
#  'AddressLine4': '',
#  'BusinessName': 'Oriental Cottage',
#  'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  'ChangesByServerID': 0,
#  'Distance': 4661.334349371914,
#  'FHRSID': 107710,
#  'LocalAuthorityBusinessID': '38127001007',
#  'LocalAuthorityCode': '122',
#  'LocalAuthorityEmailAddress': 'environmentalhealth@uttlesford.gov.uk',
#  'LocalAuthorityName': 'Uttlesford',
#  'LocalAuthorityWebSite': 'http://www.uttlesford.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CB10 1HD',
#  'RatingDate': '2022-03-31T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': 0,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64be8ec1a8ac077a1070a125'),
#  'geocode': {'latitude': Decimal128('52.02328'),
#              'longitude': Decimal128('0.240491')},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/107710',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 20, 'Structural': 15}}

# %%
# Convert the result to a Pandas DataFrame

hygiene_df = pd.DataFrame(results)

# Display the number of rows in the DataFrame
print(len(hygiene_df))

# Display the first 10 rows of the DataFrame
hygiene_df.head(10)
# Out:
# 41
#                         _id   FHRSID  ChangesByServerID  \
# 0  64be8ec0a8ac077a10702472   110681                  0
# 1  64be8ec0a8ac077a107027f8   612039                  0
# 2  64be8ec0a8ac077a10702b00   730933                  0
# 3  64be8ec0a8ac077a10702cf0   172735                  0
# 4  64be8ec0a8ac077a10702cfb   172953                  0
# 5  64be8ec0a8ac077a10703699   512854                  0
# 6  64be8ec0a8ac077a107038c1  1537089                  0
# 7  64be8ec0a8ac077a10704de8   155648                  0
# 8  64be8ec0a8ac077a10705231  1012883                  0
# 9  64be8ec0a8ac077a10705a41   644109                  0
#
#   LocalAuthorityBusinessID               BusinessName  \
# 0                     4029        The Chase Rest Home
# 1                1970/FOOD                 Brenalwood
# 2                1698/FOOD              Melrose Hotel
# 3             PI/000023858              Seaford Pizza
# 4             PI/000024532              Golden Palace
# 5            12/00816/BUTH           Ashby's Butchers
# 6          22/00224/RESTUN  South Sea Express Cuisine
# 7              EH/00006058              Golden Palace
# 8         17/00110/MIXED/S             The Tulip Tree
# 9                    41811                      F & S
#
#                     BusinessType  BusinessTypeID           AddressLine1  \
# 0                Caring Premises               5   5-6 Southfields Road
# 1                Caring Premises               5              Hall Lane
# 2  Hotel/bed & breakfast/gues...            7842  53 Marine Parade East
# 3         Takeaway/sandwich shop            7844          4 High Street
# 4        Restaurant/Cafe/Canteen               1         5 South Street
# 5              Retailers - other            4613   777 Southchurch Road
# 6        Restaurant/Cafe/Canteen               1    33 Alexandra Street
# 7         Takeaway/sandwich shop            7844          7 London Road
# 8        Restaurant/Cafe/Canteen               1          3 The Village
# 9              Retailers - other            4613
#
#          AddressLine2 AddressLine3  ...          LocalAuthorityWebSite  \
# 0          Eastbourne  East Sussex  ...  http://www.eastbourne.gov....
# 1  Walton-on-the-Naze        Essex  ...  http://www.tendringdc.gov.uk/
# 2      Clacton On Sea        Essex  ...  http://www.tendringdc.gov.uk/
# 3             Seaford  East Sussex  ...  http://www.lewes-eastbourn...
# 4             Seaford  East Sussex  ...  http://www.lewes-eastbourn...
# 5     Southend-On-Sea        Essex  ...     http://www.southend.gov.uk
# 6     Southend-on-sea        Essex  ...     http://www.southend.gov.uk
# 7            Rayleigh        Essex  ...     http://www.rochford.gov.uk
# 8       Chiddingstone         KENT  ...   http://www.sevenoaks.gov.uk/
# 9      81 Southernhay     Basildon  ...     http://www.basildon.gov.uk
#
#       LocalAuthorityEmailAddress                         scores  SchemeType  \
# 0  Customerfirst@eastbourne.g...  {'Hygiene': 20, 'Structura...        FHRS
# 1     fhsadmin@tendringdc.gov.uk  {'Hygiene': 20, 'Structura...        FHRS
# 2     fhsadmin@tendringdc.gov.uk  {'Hygiene': 20, 'Structura...        FHRS
# 3  ehealth.ldc@lewes-eastbour...  {'Hygiene': 20, 'Structura...        FHRS
# 4  ehealth.ldc@lewes-eastbour...  {'Hygiene': 20, 'Structura...        FHRS
# 5  EnvironmentalHealth@southe...  {'Hygiene': 20, 'Structura...        FHRS
# 6  EnvironmentalHealth@southe...  {'Hygiene': 20, 'Structura...        FHRS
# 7  customerservices@rochford....  {'Hygiene': 20, 'Structura...        FHRS
# 8  environmental.health@seven...  {'Hygiene': 20, 'Structura...        FHRS
# 9            ehs@basildon.gov.uk  {'Hygiene': 20, 'Structura...        FHRS
#
#                          geocode RightToReply     Distance NewRatingPending  \
# 0  {'longitude': 0.27694, 'la...               4613.888288            False
# 1  {'longitude': 1.278721, 'l...               4617.965824            False
# 2  {'longitude': 1.15927, 'la...               4619.656144            False
# 3  {'longitude': 0.10202, 'la...               4620.421725            False
# 4  {'longitude': 0.101446, 'l...               4620.437179            False
# 5  {'longitude': 0.736349, 'l...               4625.565258            False
# 6  {'longitude': 0.7121671, '...               4626.200132            False
# 7  {'longitude': 0.602364, 'l...               4632.276890            False
# 8  {'longitude': 0.1464499980...               4633.934041            False
# 9  {'longitude': 0.462307, 'l...               4636.552523            False
#
#                             meta                          links
# 0  {'dataSource': None, 'extr...  [{'rel': 'self', 'href': '...
# 1  {'dataSource': None, 'extr...  [{'rel': 'self', 'href': '...
# 2  {'dataSource': None, 'extr...  [{'rel': 'self', 'href': '...
# 3  {'dataSource': None, 'extr...  [{'rel': 'self', 'href': '...
# 4  {'dataSource': None, 'extr...  [{'rel': 'self', 'href': '...
# 5  {'dataSource': None, 'extr...  [{'rel': 'self', 'href': '...
# 6  {'dataSource': None, 'extr...  [{'rel': 'self', 'href': '...
# 7  {'dataSource': None, 'extr...  [{'rel': 'self', 'href': '...
# 8  {'dataSource': None, 'extr...  [{'rel': 'self', 'href': '...
# 9  {'dataSource': None, 'extr...  [{'rel': 'self', 'href': '...
#
# [10 rows x 28 columns]

# %% [markdown]
# ### 2. Which establishments in London have a `RatingValue` greater than or equal to 4?

# %%
# Find the establishments with London as the Local Authority and has a RatingValue greater than or equal to 4.

london_query = {'$and': [{'LocalAuthorityName': {'$regex': 'London'}}, {'RatingValue': {'$gte': '4'}}]}
                
# Use count_documents to display the number of documents in the result
total_london = establishments.count_documents(london_query)
print("Total documents in result:", total_london)

# Display the first document in the results using pprint
results = list(establishments.find(london_query))
for result in results:
    pprint(result)
# Out:
# Total documents in result: 0

# %%
# Convert the result to a Pandas DataFrame
london_df = pd.DataFrame(results)

# Display the number of rows in the DataFrame
print(len(london_df))

# Display the first 10 rows of the DataFrame
london_df.head(10)
# Out:
# 0
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### 3. What are the top 5 establishments with a `RatingValue` rating value of 5, sorted by lowest hygiene score, nearest to the new restaurant added, "Penang Flavours"?

# %%
# Search within 0.01 degree on either side of the latitude and longitude.
# Rating value must equal 5
# Sort by hygiene score

degree_search = 0.01
latitude = 51.49014200
longitude = 0.08384000

query = {
    'geocode.latitude': {'$gte': latitude - degree_search, '$lte': latitude + degree_search},
    'geocode.longitude': {'$gte': longitude - degree_search, '$lte': longitude + degree_search},
    'RatingValue': 5
}

sort = [('scores.Hygiene', 1)]
limit = 5

# Print the results
results = list(establishments.find(query).sort(sort).limit(limit))
pprint(results)
# Out:
# [{'AddressLine1': 'Restaurant And Premises 107A Plumstead High Street',
#   'AddressLine2': '',
#   'AddressLine3': 'Plumstead',
#   'AddressLine4': 'Greenwich',
#   'BusinessName': 'Howe and Co Fish and Chips - Van 17',
#   'BusinessType': 'Mobile caterer',
#   'BusinessTypeID': 7846,
#   'ChangesByServerID': 0,
#   'Distance': 4646.95593107927,
#   'FHRSID': 1380578,
#   'LocalAuthorityBusinessID': '14425',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE18 1SE',
#   'RatingDate': '2021-11-11T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('64be8ec1a8ac077a10707cc2'),
#   'geocode': {'latitude': Decimal128('51.4875335693359'),
#               'longitude': Decimal128('0.0925370007753372')},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1380578',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}},
#  {'AddressLine1': '17 Lakedale Road',
#   'AddressLine2': '',
#   'AddressLine3': 'Plumstead',
#   'AddressLine4': 'Greenwich',
#   'BusinessName': 'Lumbini Grocery Ltd T/A Al-Iman',
#   'BusinessType': 'Retailers - other',
#   'BusinessTypeID': 4613,
#   'ChangesByServerID': 0,
#   'Distance': 4646.975587048333,
#   'FHRSID': 909912,
#   'LocalAuthorityBusinessID': 'PI/000201100',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE18 1PP',
#   'RatingDate': '2020-10-20T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('64be8ec1a8ac077a10707cee'),
#   'geocode': {'latitude': Decimal128('51.4871632'),
#               'longitude': Decimal128('0.0916256')},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/909912',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 5}},
#  {'AddressLine1': '35 Lakedale Road',
#   'AddressLine2': '',
#   'AddressLine3': 'Plumstead',
#   'AddressLine4': 'Greenwich',
#   'BusinessName': 'Atlantic Fish Bar',
#   'BusinessType': 'Takeaway/sandwich shop',
#   'BusinessTypeID': 7844,
#   'ChangesByServerID': 0,
#   'Distance': 4646.974611855838,
#   'FHRSID': 694478,
#   'LocalAuthorityBusinessID': 'PI/000086506',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE18 1PR',
#   'RatingDate': '2021-06-16T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('64be8ec1a8ac077a10707ceb'),
#   'geocode': {'latitude': Decimal128('51.4867296'),
#               'longitude': Decimal128('0.0912164')},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/694478',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 5, 'Hygiene': 0, 'Structural': 0}},
#  {'AddressLine1': '144 - 146 Plumstead High Street',
#   'AddressLine2': '',
#   'AddressLine3': 'Plumstead',
#   'AddressLine4': 'Greenwich',
#   'BusinessName': 'Iceland',
#   'BusinessType': 'Retailers - supermarkets/hypermarkets',
#   'BusinessTypeID': 7840,
#   'ChangesByServerID': 0,
#   'Distance': 4646.946071297699,
#   'FHRSID': 695223,
#   'LocalAuthorityBusinessID': 'PI/000178842',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE18 1JQ',
#   'RatingDate': '2019-11-13T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('64be8ec1a8ac077a10707ca4'),
#   'geocode': {'latitude': Decimal128('51.4871482849121'),
#               'longitude': Decimal128('0.0924199968576431')},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/695223',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 5, 'Hygiene': 0, 'Structural': 5}},
#  {'AddressLine1': '130 - 132 Plumstead High Street',
#   'AddressLine2': '',
#   'AddressLine3': 'Plumstead',
#   'AddressLine4': 'Greenwich',
#   'BusinessName': 'Volunteer',
#   'BusinessType': 'Pub/bar/nightclub',
#   'BusinessTypeID': 7843,
#   'ChangesByServerID': 0,
#   'Distance': 4646.965634598608,
#   'FHRSID': 694609,
#   'LocalAuthorityBusinessID': 'PI/000116619',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE18 1JQ',
#   'RatingDate': '2019-08-05T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('64be8ec1a8ac077a10707cd2'),
#   'geocode': {'latitude': Decimal128('51.4873437'),
#               'longitude': Decimal128('0.09208')},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/694609',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}}]

# %%
# Convert the result to a Pandas DataFrame
lat_long_df = pd.DataFrame(results)

# Display the number of rows in the DataFrame
print(len(lat_long_df))

# Display the first 5 rows of the DataFrame
lat_long_df
# Out:
# 5
#                         _id   FHRSID  ChangesByServerID  \
# 0  64be8ec1a8ac077a10707cc2  1380578                  0
# 1  64be8ec1a8ac077a10707cee   909912                  0
# 2  64be8ec1a8ac077a10707ceb   694478                  0
# 3  64be8ec1a8ac077a10707ca4   695223                  0
# 4  64be8ec1a8ac077a10707cd2   694609                  0
#
#   LocalAuthorityBusinessID                   BusinessName  \
# 0                    14425  Howe and Co Fish and Chips...
# 1             PI/000201100  Lumbini Grocery Ltd T/A Al...
# 2             PI/000086506              Atlantic Fish Bar
# 3             PI/000178842                        Iceland
# 4             PI/000116619                      Volunteer
#
#                     BusinessType  BusinessTypeID  \
# 0                 Mobile caterer            7846
# 1              Retailers - other            4613
# 2         Takeaway/sandwich shop            7844
# 3  Retailers - supermarkets/h...            7840
# 4              Pub/bar/nightclub            7843
#
#                     AddressLine1 AddressLine2 AddressLine3  ...  \
# 0  Restaurant And Premises 10...                 Plumstead  ...
# 1               17 Lakedale Road                 Plumstead  ...
# 2               35 Lakedale Road                 Plumstead  ...
# 3  144 - 146 Plumstead High S...                 Plumstead  ...
# 4  130 - 132 Plumstead High S...                 Plumstead  ...
#
#            LocalAuthorityWebSite    LocalAuthorityEmailAddress  \
# 0  http://www.royalgreenwich....  health@royalgreenwich.gov.uk
# 1  http://www.royalgreenwich....  health@royalgreenwich.gov.uk
# 2  http://www.royalgreenwich....  health@royalgreenwich.gov.uk
# 3  http://www.royalgreenwich....  health@royalgreenwich.gov.uk
# 4  http://www.royalgreenwich....  health@royalgreenwich.gov.uk
#
#                           scores  SchemeType                        geocode  \
# 0  {'Hygiene': 0, 'Structural...        FHRS  {'longitude': 0.0925370007...
# 1  {'Hygiene': 0, 'Structural...        FHRS  {'longitude': 0.0916256, '...
# 2  {'Hygiene': 0, 'Structural...        FHRS  {'longitude': 0.0912164, '...
# 3  {'Hygiene': 0, 'Structural...        FHRS  {'longitude': 0.0924199968...
# 4  {'Hygiene': 0, 'Structural...        FHRS  {'longitude': 0.09208, 'la...
#
#   RightToReply     Distance NewRatingPending                           meta  \
# 0               4646.955931            False  {'dataSource': None, 'extr...
# 1               4646.975587            False  {'dataSource': None, 'extr...
# 2               4646.974612            False  {'dataSource': None, 'extr...
# 3               4646.946071            False  {'dataSource': None, 'extr...
# 4               4646.965635            False  {'dataSource': None, 'extr...
#
#                            links
# 0  [{'rel': 'self', 'href': '...
# 1  [{'rel': 'self', 'href': '...
# 2  [{'rel': 'self', 'href': '...
# 3  [{'rel': 'self', 'href': '...
# 4  [{'rel': 'self', 'href': '...
#
# [5 rows x 28 columns]

# %% [markdown]
# ### 4. How many establishments in each Local Authority area have a hygiene score of 0?

# %%
# Create a pipeline that: 
# 1. Matches establishments with a hygiene score of 0
# 2. Groups the matches by Local Authority
# 3. Sorts the matches from highest to lowest

match_query = {'$match': {'scores.Hygiene': 20}}

group_query = {'$group': {'_id': "$LocalAuthorityName"}}

sort_values =  {'$sort': { 'score.Hygiene': 1 }}

pipeline = [match_query, group_query, sort_values]

results = list(establishments.aggregate(pipeline))

# Print the number of documents in the result

print("Number of documents in result: ", len(results))

# Print the first 10 results
pprint(results[0:10])
# Out:
# Number of documents in result:  17
# [{'_id': 'Havering'},
#  {'_id': 'Rochford'},
#  {'_id': 'Basildon'},
#  {'_id': 'Newham'},
#  {'_id': 'Eastbourne'},
#  {'_id': 'Waltham Forest'},
#  {'_id': 'Bexley'},
#  {'_id': 'Brentwood'},
#  {'_id': 'Lewes'},
#  {'_id': 'Greenwich'}]

# %%
# Convert the result to a Pandas DataFrame

zero_hygiene_df = pd.DataFrame(results)

# Display the number of rows in the DataFrame

print("Rows in DataFrame: ", len(zero_hygiene_df))

# Display the first 10 rows of the DataFrame

zero_hygiene_df.head(10)
# Out:
# Rows in DataFrame:  17
#               _id
# 0        Havering
# 1        Rochford
# 2        Basildon
# 3          Newham
# 4      Eastbourne
# 5  Waltham Forest
# 6          Bexley
# 7       Brentwood
# 8           Lewes
# 9       Greenwich
